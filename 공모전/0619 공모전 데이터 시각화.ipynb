# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# matplotlib 한글 깨짐 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:\Windows\Fonts\malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv('credit_card_data(utf8).txt')

# %%
df.head()
# Out:
#   pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0   L011  2016      1        812        2   서울  NaN  10대       55000
# 1   L011  2016      2        773        4   서울  NaN  10대      380000
# 2   L011  2016      3        771        4   서울  NaN  10대      387000
# 3   L011  2016      4        770        4   서울  NaN  10대      412000
# 4   L011  2016      5        771        4   서울  NaN  10대      414000
#
#    num_opencard  ...  monthly_installments_loan  monthly_insurance_loan  \
# 0          1.44  ...                          0                       0
# 1          1.71  ...                     510000                  220000
# 2          1.75  ...                     490000                  210000
# 3          1.76  ...                     510000                  240000
# 4          1.75  ...                     490000                  340000
#
#    monthly_sbk_loan  loan_commitment  inst_rep_loanb  ls_rep_loanb  \
# ...

# %%
data_by_sex = df[df.pop_cd.str[0]=='Y'] # 지역x, 성별o

# %%
data_by_loc = df[df.pop_cd.str[0]=='L'] # 지역o, 성별x
data_by_loc

# %%
# 총 대출 금액 X 연령별
sns.barplot(x="ages", y="monthly_bk_loan", data=df)

# %%
# 총 대출 금액 X 성별
sns.barplot(x="sex", y="monthly_bk_loan", data=df)

# %%
# 총 대출 금액 X 지역별
sns.barplot(x="city", y="monthly_bk_loan", data=df)

# %%
# 총 대출 금액 X 년도별
sns.barplot(x="year", y="monthly_bk_loan", data=df)

# %%
# 총 대출 금액 X 월별
sns.lmplot(x="month", y="monthly_bk_loan", hue='year',data=df)

# %%
# 총 대출 금액 X 월별
sns.barplot(x="month", y="monthly_bk_loan", hue='year',data=df)

# %%
# 총 대출 금액 X 그룹별
sns.barplot(x="pop_cd", y="monthly_bk_loan", data=df)

# %%
sns.barplot(x="year", y="monthly_bk_loan", hue='month',data=df)

# %%
sns.barplot(x="avg_rat", y="monthly_bk_loan", hue='month',data=df)

# %%
sns.barplot(x="ages", y="credit_card_payment", data=df)

# %%
sns.barplot(x="ages", y="credit_card_payment", hue="sex", data=df)

# %%
sns.barplot(x="ages", y="credit_card_installments_payment", hue="sex", data=df)

# %%
df['pop_cd_1st']=df.pop_cd.str[0]

# %%
df.head()
# Out:
#   pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0   L011  2016      1        812        2   서울  NaN  10대       55000
# 1   L011  2016      2        773        4   서울  NaN  10대      380000
# 2   L011  2016      3        771        4   서울  NaN  10대      387000
# 3   L011  2016      4        770        4   서울  NaN  10대      412000
# 4   L011  2016      5        771        4   서울  NaN  10대      414000
#
#    num_opencard  ...  monthly_insurance_loan  monthly_sbk_loan  \
# 0          1.44  ...                       0                 0
# 1          1.71  ...                  220000           1020000
# 2          1.75  ...                  210000           1140000
# 3          1.76  ...                  240000           1340000
# 4          1.75  ...                  340000           1490000
#
#    loan_commitment  inst_rep_loanb  ls_rep_loanb  credit_loan  mortgage_loan  \
# 0          1120000         8210000      78020000     92170000       87260000
# ...

# %%
fig = plt.figure()
fig.set_size_inches(10,5)

ax_1 = fig.add_subplot(1,2,1) # 1X2 그리드의 첫번째 subplot
ax_2 = fig.add_subplot(1,2,2)

ax_1.plot(X_1, Y_1, c="b")
ax_2.plot(X_2, Y_2, c="g")
plt.show()

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment', data=df)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment',hue='sex', data=df)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment',hue='ages', data=df)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment',hue='city', data=df)

# %%
sns.lmplot(x='credit_loan', y='mortgage_loan',hue='sex', data=df)

# %%
sns.lmplot(x='credit_loan', y='mortgage_loan', hue='ages', data=df)

# %%
sns.lmplot(x='credit_loan', y='mortgage_loan',hue='city', data=df)

# %%
sns.lmplot(x='inst_rep_loanb', y='ls_rep_loanb',data=df)

# %%
sns.lmplot(x='inst_rep_loanb', y='ls_rep_loanb',hue='sex', data=df)

# %%
sns.lmplot(x='inst_rep_loanb', y='ls_rep_loanb',hue='ages', data=df)

# %%
sns.lmplot(x='inst_rep_loanb', y='ls_rep_loanb',hue='city', data=df)

# %%
sns.barplot(x='ages', y='avg_rat', data=df)

# %%
sns.barplot(x='city', y='avg_rat', data=df)

# %%
sns.barplot(x='sex', y='avg_rat', data=df)

# %%
sns.barplot(x='city', y='mortgage_loan', data=df)

# %%
sns.barplot(x='avg_rat', y='mortgage_loan', data=df)

# %%
sns.barplot(x='month', y='mortgage_loan', data=df)

# %%
sns.barplot(x='sex', y='mortgage_loan', data=df)

# %%
sns.barplot(x='ages', y='mortgage_loan', data=df)
