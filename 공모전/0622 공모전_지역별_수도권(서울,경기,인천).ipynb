# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# matplotlib 한글 깨짐 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:\Windows\Fonts\malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv('credit_card_data(utf8).txt')

# %%
data_by_sex = df[df.pop_cd.str[0]=='Y'] # 지역x, 성별o
data_by_loc = df[df.pop_cd.str[0]=='L'] # 지역o, 성별x

# %%
# data_by_sex_90s = data_by_sex[data_by_sex.ages=='90대'] # 90대, 성별o
# data_by_loc_90s = data_by_loc[data_by_loc.ages=='90대'] # 90대, 지역o

# %%
data_by_seoul = data_by_loc[data_by_loc.city=='서울']

# %%
data_by_incheon = data_by_loc[data_by_loc.city=='인천']

# %%
data_by_gyeonggi = data_by_loc[data_by_loc.city=='경기']

# %%
data_by_seoul_10s = data_by_seoul[data_by_seoul.ages=='10대']
data_by_seoul_20s = data_by_seoul[data_by_seoul.ages=='20대']
data_by_seoul_30s = data_by_seoul[data_by_seoul.ages=='30대']
data_by_seoul_40s = data_by_seoul[data_by_seoul.ages=='40대']
data_by_seoul_50s = data_by_seoul[data_by_seoul.ages=='50대']
data_by_seoul_60s = data_by_seoul[data_by_seoul.ages=='60대']
data_by_seoul_70s = data_by_seoul[data_by_seoul.ages=='70대']
data_by_seoul_80s = data_by_seoul[data_by_seoul.ages=='80대']
data_by_seoul_90s = data_by_seoul[data_by_seoul.ages=='90대']

# %%
data_by_seoul_10s.head()
# Out:
#   pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0   L011  2016      1        812        2   서울  NaN  10대       55000
# 1   L011  2016      2        773        4   서울  NaN  10대      380000
# 2   L011  2016      3        771        4   서울  NaN  10대      387000
# 3   L011  2016      4        770        4   서울  NaN  10대      412000
# 4   L011  2016      5        771        4   서울  NaN  10대      414000
#
#    num_opencard  ...  monthly_installments_loan  monthly_insurance_loan  \
# 0          1.44  ...                          0                       0
# 1          1.71  ...                     510000                  220000
# 2          1.75  ...                     490000                  210000
# 3          1.76  ...                     510000                  240000
# 4          1.75  ...                     490000                  340000
#
#    monthly_sbk_loan  loan_commitment  inst_rep_loanb  ls_rep_loanb  \
# ...

# %%
data_by_seoul_10s.columns
# Out:
# Index(['pop_cd', 'year', 'month', 'avg_score', 'avg_rat', 'city', 'sex',
#        'ages', 'population', 'num_opencard', 'num_usecard',
#        'monthly_card_spend', 'monthly_lc', 'monthly_loan', 'monthly_bk_loan',
#        'monthly_cd_loan', 'monthly_installments_loan',
#        'monthly_insurance_loan', 'monthly_sbk_loan', 'loan_commitment',
#        'inst_rep_loanb', 'ls_rep_loanb', 'credit_loan', 'mortgage_loan',
#        'credit_card_payment', 'credit_card_installments_payment'],
#       dtype='object')

# %%
# data_by_seoul.corr()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(data=data_by_seoul.corr(), annot=True,
           fmt='.2f', linewidths=.5, cmap='Blues')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_loc['city']
# y1= data_by_seoul['monthly_bk_loan']
y2= data_by_loc['monthly_cd_loan']
y3= data_by_loc['monthly_installments_loan']
y4= data_by_loc['monthly_insurance_loan']
y5= data_by_loc['monthly_sbk_loan']

# ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='monthly_cd_loan')
ax.plot(x,y3,'g',label='monthly_installments_loan')
ax.plot(x,y4,'k',label='monthly_insurance_loan')
ax.plot(x,y5,'c',label='monthly_sbk_loan')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_seoul['ages']
# y1= data_by_seoul['monthly_bk_loan']
y2= data_by_seoul['monthly_cd_loan']
y3= data_by_seoul['monthly_installments_loan']
y4= data_by_seoul['monthly_insurance_loan']
y5= data_by_seoul['monthly_sbk_loan']

# ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.plot(x,y3,'g',label='Green')
ax.plot(x,y4,'k',label='Black')
ax.plot(x,y5,'c',label='Cyan')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_incheon['ages']
# y1= data_by_incheon['monthly_bk_loan']
y2= data_by_incheon['monthly_cd_loan']
y3= data_by_incheon['monthly_installments_loan']
y4= data_by_incheon['monthly_insurance_loan']
y5= data_by_incheon['monthly_sbk_loan']

# ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.plot(x,y3,'g',label='Green')
ax.plot(x,y4,'k',label='Black')
ax.plot(x,y5,'c',label='Cyan')

ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_incheon['ages']
# y1= data_by_incheon['monthly_bk_loan']
y2= data_by_incheon['monthly_cd_loan']
y3= data_by_incheon['monthly_installments_loan']
y4= data_by_incheon['monthly_insurance_loan']
y5= data_by_incheon['monthly_sbk_loan']

# ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.plot(x,y3,'g',label='Green')
ax.plot(x,y4,'k',label='Black')
ax.plot(x,y5,'c',label='Cyan')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_gyeonggi['ages']
# y1= data_by_gyeonggi['monthly_bk_loan']
y2= data_by_gyeonggi['monthly_cd_loan']
y3= data_by_gyeonggi['monthly_installments_loan']
y4= data_by_gyeonggi['monthly_insurance_loan']
y5= data_by_gyeonggi['monthly_sbk_loan']

# ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.plot(x,y3,'g',label='Green')
ax.plot(x,y4,'k',label='Black')
ax.plot(x,y5,'c',label='Cyan')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_gyeonggi['ages']
# y1= data_by_gyeonggi['monthly_bk_loan']
y2= data_by_gyeonggi['monthly_cd_loan']
y3= data_by_gyeonggi['monthly_installments_loan']
y4= data_by_gyeonggi['monthly_insurance_loan']
y5= data_by_gyeonggi['monthly_sbk_loan']

# ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.plot(x,y3,'g',label='Green')
ax.plot(x,y4,'k',label='Black')
ax.plot(x,y5,'c',label='Cyan')
ax.legend(loc=0)

# %%
sns.barplot(x='ages', y='monthly_bk_loan', data=data_by_seoul)

# %%
sns.barplot(x='ages', y='monthly_cd_loan', data=data_by_seoul)

# %%
sns.barplot(x='ages', y='monthly_installments_loan', data=data_by_seoul)

# %%
sns.barplot(x='ages', y='monthly_insurance_loan', data=data_by_seoul)

# %%
sns.barplot(x='ages', y='monthly_sbk_loan', data=data_by_seoul)

# %%
sns.barplot(x='ages', y='monthly_sbk_loan', data=df)

# %%
sns.barplot(x='month', y='monthly_sbk_loan', data=df)

# %%
sns.barplot(x='city', y='monthly_sbk_loan', data=df)

# %%
sns.barplot(x='sex', y='monthly_sbk_loan', data=data_by_sex)

# %%
sns.barplot(x='month', y='monthly_sbk_loan', hue='sex', data=data_by_sex)

# %%
sns.lmplot(x='month', y='monthly_sbk_loan', hue='sex', data=data_by_sex)

# %%
sns.barplot(x='avg_rat', y='monthly_sbk_loan', hue='sex', data=df)

# %%
sns.barplot(x='month', y='monthly_sbk_loan', hue='avg_rat', data=df)

# %%
sns.lmplot(x='month', y='monthly_sbk_loan', hue='avg_rat', data=df)

# %%
sns.lmplot(x='num_opencard', y='monthly_sbk_loan',data=df)

# %%
sns.lmplot(x='num_opencard', y='monthly_sbk_loan', hue='avg_rat', data=df)

# %% [markdown]
# > 10대는 저축은행 업종에서의 대출금액이 많다.<br>

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_seoul['ages']
y1= data_by_seoul['credit_loan']
y2= data_by_seoul['mortgage_loan']

ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_incheon['ages']
y1= data_by_incheon['credit_loan']
y2= data_by_incheon['mortgage_loan']

ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_gyeonggi['ages']
y1= data_by_gyeonggi['credit_loan']
y2= data_by_gyeonggi['mortgage_loan']

ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.legend(loc=0)

# %% [markdown]
# > 신용대출은 90대가 가장 많이 받는다.
# > 50,60,70,80대로 갈수록 담보대출이 감소한다.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_seoul['ages']
y1= data_by_seoul['credit_card_payment']
y2= data_by_seoul['credit_card_installments_payment']

ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_incheon['ages']
y1= data_by_incheon['credit_card_payment']
y2= data_by_incheon['credit_card_installments_payment']

ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
x = data_by_gyeonggi['ages']
y1= data_by_gyeonggi['credit_card_payment']
y2= data_by_gyeonggi['credit_card_installments_payment']

ax.plot(x,y1,'r',label='Red')
ax.plot(x,y2,'y',label='Yellow')
ax.legend(loc=0)

# %% [markdown]
# > 20대에서 30대로 넘어갈때 신용카드 일시불 이용금액이 급격히 증가한다.

# %%
fig = plt.figure()
ax = fig.add_subplot()

# y1= data_by_seoul['monthly_card_spend']
y2= data_by_seoul['monthly_lc']
y3= data_by_seoul['monthly_loan']

# ax.plot(y1,'r',label='monthly_card_loan')
ax.plot(y2,'y',label='monthly_lc')
ax.plot(y3,'g',label='monthly_loan')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot()

y1= data_by_gyeonggi['monthly_card_spend']
y2= data_by_gyeonggi['monthly_lc']
y3= data_by_gyeonggi['monthly_loan']

ax.plot(y1,'r',label='monthly_card_loan')
# ax.plot(y2,'y',label='monthly_lc')
# ax.plot(y3,'g',label='monthly_loan')
ax.legend(loc=0)

# %%
fig = plt.figure()
ax = fig.add_subplot()

y1= data_by_incheon['monthly_card_spend']
y2= data_by_incheon['monthly_lc']
y3= data_by_incheon['monthly_loan']

# ax.plot(y1,'r',label='monthly_card_loan')
ax.plot(y2,'y',label='monthly_lc')
ax.plot(y3,'g',label='monthly_loan')
ax.legend(loc=0)

# %%
sns.barplot(x='month', y='monthly_card_spend', data=data_by_seoul)
#월 카드 이용 총 금액은 3월이 가장 적다.
#3월에 카드 이용 시 할인혜택을 제공하자

# %%
sns.barplot(x='month', y='monthly_cd_loan', data=data_by_seoul)

# %%
sns.barplot(x='month', y='monthly_installments_loan', data=data_by_seoul)

# %%
sns.barplot(x='month', y='monthly_sbk_loan', data=data_by_seoul)
# 저축은행은 1월이 가장 적다

# %%
sns.barplot(x='month', y='num_opencard', data=data_by_seoul)
# 카드 대출은 1월이 가장 적지만 개설수는 가장 많다.

# %%
sns.barplot(x='month', y='num_opencard', data=data_by_seoul_90s)

# %%
plt.plot('ls_rep_loanb', data=data_by_seoul)
