# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# matplotlib 한글 깨짐 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:\Windows\Fonts\malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv('credit_card_data(utf8).txt')

# %%
df['card_use_rate'] = df['num_usecard'] / df['num_opencard'] * 100

# %%
data_by_sex = df[df.pop_cd.str[0]=='Y'] # 지역x, 성별o
data_by_loc = df[df.pop_cd.str[0]=='L'] # 지역o, 성별x

# %%
data_by_seoul = data_by_loc[data_by_loc['city'] =='서울']
data_by_inchoen = data_by_loc[data_by_loc['city'] =='인천']
data_by_gyeonggi = data_by_loc[data_by_loc['city'] =='경기']

data_by_capital = pd.concat([data_by_seoul,data_by_inchoen,data_by_gyeonggi])
data_by_capital
# Out:
#      pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0      L011  2016      1        812        2   서울  NaN  10대       55000
# 1      L011  2016      2        773        4   서울  NaN  10대      380000
# 2      L011  2016      3        771        4   서울  NaN  10대      387000
# 3      L011  2016      4        770        4   서울  NaN  10대      412000
# 4      L011  2016      5        771        4   서울  NaN  10대      414000
# 5      L011  2016      6        771        4   서울  NaN  10대      410000
# 6      L011  2016      7        772        4   서울  NaN  10대      407000
# 7      L011  2016      8        772        4   서울  NaN  10대      403000
# 8      L011  2016      9        772        4   서울  NaN  10대      399000
# 9      L011  2016     10        773        4   서울  NaN  10대      395000
# 10     L011  2016     11        775        4   서울  NaN  10대      390000
# 11     L011  2016     12        775        4   서울  NaN  10대      387000
# ...

# %%
data_by_seoul_10s = data_by_seoul[data_by_seoul.ages=='10대']

# %%
df.columns
# Out:
# Index(['pop_cd', 'year', 'month', 'avg_score', 'avg_rat', 'city', 'sex',
#        'ages', 'population', 'num_opencard', 'num_usecard',
#        'monthly_card_spend', 'monthly_lc', 'monthly_loan', 'monthly_bk_loan',
#        'monthly_cd_loan', 'monthly_installments_loan',
#        'monthly_insurance_loan', 'monthly_sbk_loan', 'loan_commitment',
#        'inst_rep_loanb', 'ls_rep_loanb', 'credit_loan', 'mortgage_loan',
#        'credit_card_payment', 'credit_card_installments_payment',
#        'card_use_rate'],
#       dtype='object')

# %%
data_by_capital.head()
# Out:
#   pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0   L011  2016      1        812        2   서울  NaN  10대       55000
# 1   L011  2016      2        773        4   서울  NaN  10대      380000
# 2   L011  2016      3        771        4   서울  NaN  10대      387000
# 3   L011  2016      4        770        4   서울  NaN  10대      412000
# 4   L011  2016      5        771        4   서울  NaN  10대      414000
#
#    num_opencard  ...  monthly_insurance_loan  monthly_sbk_loan  \
# 0          1.44  ...                       0                 0
# 1          1.71  ...                  220000           1020000
# 2          1.75  ...                  210000           1140000
# 3          1.76  ...                  240000           1340000
# 4          1.75  ...                  340000           1490000
#
#    loan_commitment  inst_rep_loanb  ls_rep_loanb  credit_loan  mortgage_loan  \
# 0          1120000         8210000      78020000     92170000       87260000
# ...

# %%
sns.barplot(x='city', y='monthly_bk_loan', data=data_by_capital)

# %%
sns.barplot(x='city', y='monthly_cd_loan', data=data_by_capital)

# %%
sns.boxplot(x='city', y='monthly_insurance_loan', data=data_by_capital)

# %%
sns.boxplot(x='city', y='monthly_sbk_loan', data=data_by_capital)

# %%
# 은행 업종
sns.boxplot(x='city', y='monthly_bk_loan', data=data_by_capital)

# %%
# 카드 업종
sns.boxplot(x='city', y='monthly_cd_loan', data=data_by_capital)

# %%
# 할부금융 업종
sns.boxplot(x='city', y='monthly_installments_loan', data=data_by_capital)

# %%
# 보험 업종
sns.boxplot(x='city', y='monthly_insurance_loan', data=data_by_capital)

# %%
# 저축은행 업종
sns.boxplot(x='city', y='monthly_sbk_loan', data=data_by_capital)

# %%
sns.barplot(x='city', y='loan_commitment', data=data_by_capital)

# %%
sns.barplot(x='city', y='inst_rep_loanb', data=data_by_capital)

# %%
sns.barplot(x='city', y='ls_rep_loanb', data=data_by_capital)

# %%
sns.barplot(x='city', y='credit_loan', data=data_by_capital)

# %%
sns.barplot(x='city', y='mortgage_loan', data=data_by_capital)

# %%
sns.barplot(x='city', y='credit_card_payment', data=data_by_capital)

# %%
sns.barplot(x='city', y='credit_card_installments_payment', data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='avg_rat', data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='monthly_lc', hue='city', data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='monthly_loan', hue='city', data=data_by_capital)

# %%
sns.lmplot(x='avg_rat', y='monthly_loan', hue='city', data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='monthly_bk_loan', hue='city',data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='loan_commitment', hue='city',data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='inst_rep_loanb', hue='city', data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='ls_rep_loanb', hue='city',data=data_by_capital)

# %%
sns.lmplot(x='avg_score', y='mortgage_loan', hue='city',data=data_by_capital)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment', hue='city', data=data_by_capital)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment', hue='sex', data=data_by_sex)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment', hue='ages', data=data_by_capital) #90대는 약간 다르네?

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment', hue='avg_rat', data=data_by_capital)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment', data=data_by_capital)

# %%
sns.lmplot(x='credit_card_payment', y='credit_card_installments_payment', hue='avg_rat', data=data_by_seoul)

# %%
import folium

# %%
map_osm = folium.Map(location=[37.566345, 126.977893])
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_osm.choropleth(geo_path=state_geo, data=state_data,

# %%
map_pos = [37.566345, 126.977893]
map = folium.Map(location=map_pos)
folium.CircleMarker(location=map_pos, radius=400, 
                    color='#3186cc', fill_color='#3186cc').add_to(map)

marker_pos1 = [35.686626, 139.699062]
marker_pos2 = [35.689511, 139.700602]

folium.Marker(marker_pos1).add_to(map)
folium.Marker(marker_pos2).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
