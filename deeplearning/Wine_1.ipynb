# %%
from keras.models import Sequential, load_model
from keras.layers.core import Dense
from keras.callbacks import ModelCheckpoint

import pandas as pd
import numpy as np
import os
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
df_pre = pd.read_csv('wine.csv', header=None)
df = df_pre.sample(frac=1)

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 14:38:07.200628  3536 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 14:38:07.201627  3536 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 14:38:07.203628  3536 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])
# Out:
# W0719 14:38:20.238838  3536 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0719 14:38:20.257817  3536 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0719 14:38:20.262816  3536 deprecation.py:323] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

# %%
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True) #앞서저장한 파일보다 나을때만 저장

# %%
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])
# Out:
# W0719 14:38:25.513038  3536 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.31193, saving model to ./model/01-0.3119.hdf5
#
# Epoch 00002: val_loss improved from 0.31193 to 0.25415, saving model to ./model/02-0.2542.hdf5
#
# Epoch 00003: val_loss improved from 0.25415 to 0.21343, saving model to ./model/03-0.2134.hdf5
#
# Epoch 00004: val_loss improved from 0.21343 to 0.20457, saving model to ./model/04-0.2046.hdf5
#
# Epoch 00005: val_loss improved from 0.20457 to 0.19696, saving model to ./model/05-0.1970.hdf5
#
# Epoch 00006: val_loss improved from 0.19696 to 0.18618, saving model to ./model/06-0.1862.hdf5
#
# Epoch 00007: val_loss improved from 0.18618 to 0.18057, saving model to ./model/07-0.1806.hdf5
#
# Epoch 00008: val_loss improved from 0.18057 to 0.18004, saving model to ./model/08-0.1800.hdf5
#
# Epoch 00009: val_loss improved from 0.18004 to 0.17969, saving model to ./model/09-0.1797.hdf5
#
# Epoch 00010: val_loss improved from 0.17969 to 0.17658, saving model to ./model/10-0.1766.hdf5
#
# Epoch 00011: val_loss improved from 0.17658 to 0.16666, saving model to ./model/11-0.1667.hdf5
#
# Epoch 00012: val_loss improved from 0.16666 to 0.16327, saving model to ./model/12-0.1633.hdf5
#
# Epoch 00013: val_loss did not improve from 0.16327
#
# Epoch 00014: val_loss improved from 0.16327 to 0.15827, saving model to ./model/14-0.1583.hdf5
#
# Epoch 00015: val_loss improved from 0.15827 to 0.15711, saving model to ./model/15-0.1571.hdf5
#
# Epoch 00016: val_loss improved from 0.15711 to 0.15137, saving model to ./model/16-0.1514.hdf5
#
# Epoch 00017: val_loss improved from 0.15137 to 0.14845, saving model to ./model/17-0.1484.hdf5
#
# Epoch 00018: val_loss improved from 0.14845 to 0.14693, saving model to ./model/18-0.1469.hdf5
#
# Epoch 00019: val_loss improved from 0.14693 to 0.14316, saving model to ./model/19-0.1432.hdf5
#
# Epoch 00020: val_loss did not improve from 0.14316
#
# Epoch 00021: val_loss improved from 0.14316 to 0.13709, saving model to ./model/21-0.1371.hdf5
#
# Epoch 00022: val_loss improved from 0.13709 to 0.13390, saving model to ./model/22-0.1339.hdf5
#
# Epoch 00023: val_loss did not improve from 0.13390
#
# Epoch 00024: val_loss improved from 0.13390 to 0.12782, saving model to ./model/24-0.1278.hdf5
#
# Epoch 00025: val_loss improved from 0.12782 to 0.12560, saving model to ./model/25-0.1256.hdf5
#
# Epoch 00026: val_loss improved from 0.12560 to 0.12113, saving model to ./model/26-0.1211.hdf5
#
# Epoch 00027: val_loss improved from 0.12113 to 0.12095, saving model to ./model/27-0.1209.hdf5
#
# Epoch 00028: val_loss improved from 0.12095 to 0.11764, saving model to ./model/28-0.1176.hdf5
#
# Epoch 00029: val_loss did not improve from 0.11764
#
# Epoch 00030: val_loss improved from 0.11764 to 0.11169, saving model to ./model/30-0.1117.hdf5
#
# Epoch 00031: val_loss did not improve from 0.11169
#
# Epoch 00032: val_loss improved from 0.11169 to 0.10993, saving model to ./model/32-0.1099.hdf5
#
# Epoch 00033: val_loss did not improve from 0.10993
#
# Epoch 00034: val_loss did not improve from 0.10993
#
# Epoch 00035: val_loss improved from 0.10993 to 0.10307, saving model to ./model/35-0.1031.hdf5
#
# Epoch 00036: val_loss did not improve from 0.10307
#
# Epoch 00037: val_loss improved from 0.10307 to 0.09706, saving model to ./model/37-0.0971.hdf5
#
# Epoch 00038: val_loss improved from 0.09706 to 0.09409, saving model to ./model/38-0.0941.hdf5
#
# Epoch 00039: val_loss improved from 0.09409 to 0.09310, saving model to ./model/39-0.0931.hdf5
#
# Epoch 00040: val_loss did not improve from 0.09310
#
# Epoch 00041: val_loss improved from 0.09310 to 0.09012, saving model to ./model/41-0.0901.hdf5
#
# Epoch 00042: val_loss improved from 0.09012 to 0.08608, saving model to ./model/42-0.0861.hdf5
#
# Epoch 00043: val_loss did not improve from 0.08608
#
# Epoch 00044: val_loss improved from 0.08608 to 0.08585, saving model to ./model/44-0.0858.hdf5
#
# Epoch 00045: val_loss improved from 0.08585 to 0.08472, saving model to ./model/45-0.0847.hdf5
#
# Epoch 00046: val_loss improved from 0.08472 to 0.08261, saving model to ./model/46-0.0826.hdf5
#
# Epoch 00047: val_loss improved from 0.08261 to 0.08186, saving model to ./model/47-0.0819.hdf5
#
# Epoch 00048: val_loss did not improve from 0.08186
#
# Epoch 00049: val_loss improved from 0.08186 to 0.07848, saving model to ./model/49-0.0785.hdf5
#
# Epoch 00050: val_loss did not improve from 0.07848
#
# Epoch 00051: val_loss improved from 0.07848 to 0.07667, saving model to ./model/51-0.0767.hdf5
#
# Epoch 00052: val_loss improved from 0.07667 to 0.07595, saving model to ./model/52-0.0760.hdf5
#
# Epoch 00053: val_loss did not improve from 0.07595
#
# Epoch 00054: val_loss did not improve from 0.07595
#
# Epoch 00055: val_loss did not improve from 0.07595
#
# Epoch 00056: val_loss did not improve from 0.07595
#
# Epoch 00057: val_loss improved from 0.07595 to 0.07102, saving model to ./model/57-0.0710.hdf5
#
# Epoch 00058: val_loss did not improve from 0.07102
#
# Epoch 00059: val_loss improved from 0.07102 to 0.07080, saving model to ./model/59-0.0708.hdf5
#
# Epoch 00060: val_loss improved from 0.07080 to 0.06849, saving model to ./model/60-0.0685.hdf5
#
# Epoch 00061: val_loss did not improve from 0.06849
#
# Epoch 00062: val_loss did not improve from 0.06849
#
# Epoch 00063: val_loss improved from 0.06849 to 0.06572, saving model to ./model/63-0.0657.hdf5
#
# Epoch 00064: val_loss did not improve from 0.06572
#
# Epoch 00065: val_loss did not improve from 0.06572
#
# Epoch 00066: val_loss improved from 0.06572 to 0.06362, saving model to ./model/66-0.0636.hdf5
#
# Epoch 00067: val_loss did not improve from 0.06362
#
# Epoch 00068: val_loss did not improve from 0.06362
#
# Epoch 00069: val_loss did not improve from 0.06362
#
# Epoch 00070: val_loss improved from 0.06362 to 0.06136, saving model to ./model/70-0.0614.hdf5
#
# Epoch 00071: val_loss did not improve from 0.06136
#
# Epoch 00072: val_loss did not improve from 0.06136
#
# Epoch 00073: val_loss did not improve from 0.06136
#
# Epoch 00074: val_loss improved from 0.06136 to 0.05988, saving model to ./model/74-0.0599.hdf5
#
# Epoch 00075: val_loss did not improve from 0.05988
#
# Epoch 00076: val_loss did not improve from 0.05988
#
# Epoch 00077: val_loss improved from 0.05988 to 0.05819, saving model to ./model/77-0.0582.hdf5
#
# Epoch 00078: val_loss did not improve from 0.05819
#
# Epoch 00079: val_loss did not improve from 0.05819
#
# Epoch 00080: val_loss did not improve from 0.05819
#
# Epoch 00081: val_loss improved from 0.05819 to 0.05733, saving model to ./model/81-0.0573.hdf5
#
# Epoch 00082: val_loss did not improve from 0.05733
#
# Epoch 00083: val_loss did not improve from 0.05733
#
# Epoch 00084: val_loss did not improve from 0.05733
#
# Epoch 00085: val_loss did not improve from 0.05733
#
# Epoch 00086: val_loss improved from 0.05733 to 0.05610, saving model to ./model/86-0.0561.hdf5
#
# Epoch 00087: val_loss improved from 0.05610 to 0.05528, saving model to ./model/87-0.0553.hdf5
#
# Epoch 00088: val_loss improved from 0.05528 to 0.05410, saving model to ./model/88-0.0541.hdf5
#
# Epoch 00089: val_loss did not improve from 0.05410
#
# Epoch 00090: val_loss did not improve from 0.05410
#
# Epoch 00091: val_loss did not improve from 0.05410
#
# Epoch 00092: val_loss improved from 0.05410 to 0.05341, saving model to ./model/92-0.0534.hdf5
#
# Epoch 00093: val_loss did not improve from 0.05341
#
# Epoch 00094: val_loss did not improve from 0.05341
#
# Epoch 00095: val_loss did not improve from 0.05341
#
# Epoch 00096: val_loss did not improve from 0.05341
#
# Epoch 00097: val_loss improved from 0.05341 to 0.05283, saving model to ./model/97-0.0528.hdf5
#
# Epoch 00098: val_loss did not improve from 0.05283
#
# Epoch 00099: val_loss did not improve from 0.05283
#
# Epoch 00100: val_loss improved from 0.05283 to 0.05276, saving model to ./model/100-0.0528.hdf5
#
# Epoch 00101: val_loss did not improve from 0.05276
#
# Epoch 00102: val_loss improved from 0.05276 to 0.05197, saving model to ./model/102-0.0520.hdf5
#
# Epoch 00103: val_loss did not improve from 0.05197
#
# Epoch 00104: val_loss did not improve from 0.05197
#
# Epoch 00105: val_loss did not improve from 0.05197
#
# Epoch 00106: val_loss did not improve from 0.05197
#
# Epoch 00107: val_loss did not improve from 0.05197
#
# Epoch 00108: val_loss did not improve from 0.05197
#
# Epoch 00109: val_loss did not improve from 0.05197
#
# Epoch 00110: val_loss did not improve from 0.05197
#
# Epoch 00111: val_loss improved from 0.05197 to 0.05193, saving model to ./model/111-0.0519.hdf5
#
# Epoch 00112: val_loss did not improve from 0.05193
#
# Epoch 00113: val_loss improved from 0.05193 to 0.05084, saving model to ./model/113-0.0508.hdf5
# Epoch 00114: val_loss did not improve from 0.05084
#
# Epoch 00115: val_loss did not improve from 0.05084
#
# Epoch 00116: val_loss did not improve from 0.05084
#
# Epoch 00117: val_loss did not improve from 0.05084
#
# Epoch 00118: val_loss did not improve from 0.05084
#
# Epoch 00119: val_loss did not improve from 0.05084
#
# Epoch 00120: val_loss improved from 0.05084 to 0.05071, saving model to ./model/120-0.0507.hdf5
#
# Epoch 00121: val_loss improved from 0.05071 to 0.04999, saving model to ./model/121-0.0500.hdf5
#
# Epoch 00122: val_loss did not improve from 0.04999
#
# Epoch 00123: val_loss did not improve from 0.04999
#
# Epoch 00124: val_loss improved from 0.04999 to 0.04997, saving model to ./model/124-0.0500.hdf5
#
# Epoch 00125: val_loss did not improve from 0.04997
#
# Epoch 00126: val_loss did not improve from 0.04997
#
# Epoch 00127: val_loss did not improve from 0.04997
#
# Epoch 00128: val_loss improved from 0.04997 to 0.04995, saving model to ./model/128-0.0499.hdf5
#
# Epoch 00129: val_loss improved from 0.04995 to 0.04914, saving model to ./model/129-0.0491.hdf5
#
# Epoch 00130: val_loss did not improve from 0.04914
#
# Epoch 00131: val_loss did not improve from 0.04914
#
# Epoch 00132: val_loss did not improve from 0.04914
#
# Epoch 00133: val_loss did not improve from 0.04914
#
# Epoch 00134: val_loss did not improve from 0.04914
#
# Epoch 00135: val_loss did not improve from 0.04914
#
# Epoch 00136: val_loss did not improve from 0.04914
#
# Epoch 00137: val_loss improved from 0.04914 to 0.04878, saving model to ./model/137-0.0488.hdf5
#
# Epoch 00138: val_loss improved from 0.04878 to 0.04847, saving model to ./model/138-0.0485.hdf5
#
# Epoch 00139: val_loss improved from 0.04847 to 0.04814, saving model to ./model/139-0.0481.hdf5
#
# Epoch 00140: val_loss did not improve from 0.04814
#
# Epoch 00141: val_loss did not improve from 0.04814
#
# Epoch 00142: val_loss did not improve from 0.04814
#
# Epoch 00143: val_loss did not improve from 0.04814
#
# Epoch 00144: val_loss did not improve from 0.04814
#
# Epoch 00145: val_loss improved from 0.04814 to 0.04805, saving model to ./model/145-0.0480.hdf5
#
# Epoch 00146: val_loss did not improve from 0.04805
#
# Epoch 00147: val_loss did not improve from 0.04805
#
# Epoch 00148: val_loss did not improve from 0.04805
#
# Epoch 00149: val_loss did not improve from 0.04805
#
# Epoch 00150: val_loss did not improve from 0.04805
#
# Epoch 00151: val_loss did not improve from 0.04805
#
# Epoch 00152: val_loss did not improve from 0.04805
#
# Epoch 00153: val_loss did not improve from 0.04805
#
# Epoch 00154: val_loss did not improve from 0.04805
#
# Epoch 00155: val_loss did not improve from 0.04805
#
# Epoch 00156: val_loss did not improve from 0.04805
#
# Epoch 00157: val_loss did not improve from 0.04805
#
# Epoch 00158: val_loss did not improve from 0.04805
#
# Epoch 00159: val_loss did not improve from 0.04805
#
# Epoch 00160: val_loss did not improve from 0.04805
#
# Epoch 00161: val_loss did not improve from 0.04805
#
# Epoch 00162: val_loss did not improve from 0.04805
#
# Epoch 00163: val_loss did not improve from 0.04805
#
# Epoch 00164: val_loss improved from 0.04805 to 0.04735, saving model to ./model/164-0.0473.hdf5
#
# Epoch 00165: val_loss improved from 0.04735 to 0.04723, saving model to ./model/165-0.0472.hdf5
#
# Epoch 00166: val_loss improved from 0.04723 to 0.04687, saving model to ./model/166-0.0469.hdf5
#
# Epoch 00167: val_loss did not improve from 0.04687
#
# Epoch 00168: val_loss did not improve from 0.04687
#
# Epoch 00169: val_loss did not improve from 0.04687
#
# Epoch 00170: val_loss did not improve from 0.04687
#
# Epoch 00171: val_loss did not improve from 0.04687
#
# Epoch 00172: val_loss improved from 0.04687 to 0.04550, saving model to ./model/172-0.0455.hdf5
#
# Epoch 00173: val_loss did not improve from 0.04550
#
# Epoch 00174: val_loss did not improve from 0.04550
#
# Epoch 00175: val_loss did not improve from 0.04550
#
# Epoch 00176: val_loss did not improve from 0.04550
#
# Epoch 00177: val_loss did not improve from 0.04550
#
# Epoch 00178: val_loss did not improve from 0.04550
#
# Epoch 00179: val_loss did not improve from 0.04550
#
# Epoch 00180: val_loss did not improve from 0.04550
#
# Epoch 00181: val_loss did not improve from 0.04550
#
# Epoch 00182: val_loss did not improve from 0.04550
#
# Epoch 00183: val_loss did not improve from 0.04550
#
# Epoch 00184: val_loss did not improve from 0.04550
#
# Epoch 00185: val_loss did not improve from 0.04550
#
# Epoch 00186: val_loss did not improve from 0.04550
#
# Epoch 00187: val_loss improved from 0.04550 to 0.04522, saving model to ./model/187-0.0452.hdf5
#
# Epoch 00188: val_loss did not improve from 0.04522
#
# Epoch 00189: val_loss did not improve from 0.04522
#
# Epoch 00190: val_loss did not improve from 0.04522
#
# Epoch 00191: val_loss did not improve from 0.04522
#
# Epoch 00192: val_loss did not improve from 0.04522
#
# Epoch 00193: val_loss did not improve from 0.04522
#
# Epoch 00194: val_loss did not improve from 0.04522
#
# Epoch 00195: val_loss did not improve from 0.04522
#
# Epoch 00196: val_loss did not improve from 0.04522
#
# Epoch 00197: val_loss did not improve from 0.04522
#
# Epoch 00198: val_loss did not improve from 0.04522
#
# Epoch 00199: val_loss improved from 0.04522 to 0.04514, saving model to ./model/199-0.0451.hdf5
#
# Epoch 00200: val_loss improved from 0.04514 to 0.04504, saving model to ./model/200-0.0450.hdf5
