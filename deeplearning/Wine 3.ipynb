# %%
from keras.models import Sequential, load_model
from keras.layers.core import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import os
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
seed = 0
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
df_pre = pd.read_csv('wine.csv', header=None)
df = df_pre.sample(frac=0.15)

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0719 14:52:07.021883  6680 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0719 14:52:07.023916  6680 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0719 14:52:07.025896  6680 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(loss='binary_crossentropy',
          optimizer='adam',
          metrics=['accuracy'])
# Out:
# W0719 14:52:07.098907  6680 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0719 14:52:07.115881  6680 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0719 14:52:07.119881  6680 deprecation.py:323] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

# %%
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# %%
model.fit(X, Y, validation_split=0.2, epochs=3500, batch_size=500, verbose=0, \
          callbacks=[early_stopping_callback,checkpointer])
# Out:
# W0719 14:52:07.564904  6680 deprecation_wrapper.py:119] From C:\Users\user\Anaconda3\envs\deeplearning\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 00001: val_loss improved from inf to 0.48741, saving model to ./model/01-0.4874.hdf5
#
# Epoch 00002: val_loss improved from 0.48741 to 0.46237, saving model to ./model/02-0.4624.hdf5
#
# Epoch 00003: val_loss improved from 0.46237 to 0.43635, saving model to ./model/03-0.4363.hdf5
#
# Epoch 00004: val_loss improved from 0.43635 to 0.42144, saving model to ./model/04-0.4214.hdf5
#
# Epoch 00005: val_loss improved from 0.42144 to 0.40844, saving model to ./model/05-0.4084.hdf5
#
# Epoch 00006: val_loss improved from 0.40844 to 0.39530, saving model to ./model/06-0.3953.hdf5
#
# Epoch 00007: val_loss improved from 0.39530 to 0.38690, saving model to ./model/07-0.3869.hdf5
#
# Epoch 00008: val_loss improved from 0.38690 to 0.37965, saving model to ./model/08-0.3796.hdf5
#
# Epoch 00009: val_loss improved from 0.37965 to 0.37305, saving model to ./model/09-0.3730.hdf5
#
# Epoch 00010: val_loss improved from 0.37305 to 0.36615, saving model to ./model/10-0.3662.hdf5
#
# Epoch 00011: val_loss improved from 0.36615 to 0.35993, saving model to ./model/11-0.3599.hdf5
#
# Epoch 00012: val_loss improved from 0.35993 to 0.35470, saving model to ./model/12-0.3547.hdf5
#
# Epoch 00013: val_loss improved from 0.35470 to 0.34988, saving model to ./model/13-0.3499.hdf5
#
# Epoch 00014: val_loss improved from 0.34988 to 0.34494, saving model to ./model/14-0.3449.hdf5
#
# Epoch 00015: val_loss improved from 0.34494 to 0.33892, saving model to ./model/15-0.3389.hdf5
#
# Epoch 00016: val_loss improved from 0.33892 to 0.33356, saving model to ./model/16-0.3336.hdf5
#
# Epoch 00017: val_loss improved from 0.33356 to 0.32888, saving model to ./model/17-0.3289.hdf5
#
# Epoch 00018: val_loss improved from 0.32888 to 0.32514, saving model to ./model/18-0.3251.hdf5
#
# Epoch 00019: val_loss improved from 0.32514 to 0.32360, saving model to ./model/19-0.3236.hdf5
#
# Epoch 00020: val_loss improved from 0.32360 to 0.31959, saving model to ./model/20-0.3196.hdf5
#
# Epoch 00021: val_loss improved from 0.31959 to 0.31223, saving model to ./model/21-0.3122.hdf5
#
# Epoch 00022: val_loss improved from 0.31223 to 0.30758, saving model to ./model/22-0.3076.hdf5
#
# Epoch 00023: val_loss improved from 0.30758 to 0.30336, saving model to ./model/23-0.3034.hdf5
#
# Epoch 00024: val_loss improved from 0.30336 to 0.30027, saving model to ./model/24-0.3003.hdf5
#
# Epoch 00025: val_loss improved from 0.30027 to 0.29840, saving model to ./model/25-0.2984.hdf5
#
# Epoch 00026: val_loss improved from 0.29840 to 0.29342, saving model to ./model/26-0.2934.hdf5
#
# Epoch 00027: val_loss improved from 0.29342 to 0.28757, saving model to ./model/27-0.2876.hdf5
#
# Epoch 00028: val_loss improved from 0.28757 to 0.28372, saving model to ./model/28-0.2837.hdf5
#
# Epoch 00029: val_loss improved from 0.28372 to 0.27907, saving model to ./model/29-0.2791.hdf5
#
# Epoch 00030: val_loss improved from 0.27907 to 0.27652, saving model to ./model/30-0.2765.hdf5
#
# Epoch 00031: val_loss improved from 0.27652 to 0.27235, saving model to ./model/31-0.2723.hdf5
#
# Epoch 00032: val_loss improved from 0.27235 to 0.26743, saving model to ./model/32-0.2674.hdf5
#
# Epoch 00033: val_loss improved from 0.26743 to 0.26377, saving model to ./model/33-0.2638.hdf5
#
# Epoch 00034: val_loss improved from 0.26377 to 0.26037, saving model to ./model/34-0.2604.hdf5
#
# Epoch 00035: val_loss improved from 0.26037 to 0.25877, saving model to ./model/35-0.2588.hdf5
#
# Epoch 00036: val_loss improved from 0.25877 to 0.25552, saving model to ./model/36-0.2555.hdf5
#
# Epoch 00037: val_loss improved from 0.25552 to 0.25218, saving model to ./model/37-0.2522.hdf5
#
# Epoch 00038: val_loss improved from 0.25218 to 0.24961, saving model to ./model/38-0.2496.hdf5
#
# Epoch 00039: val_loss improved from 0.24961 to 0.24745, saving model to ./model/39-0.2474.hdf5
#
# Epoch 00040: val_loss improved from 0.24745 to 0.24554, saving model to ./model/40-0.2455.hdf5
#
# Epoch 00041: val_loss improved from 0.24554 to 0.24459, saving model to ./model/41-0.2446.hdf5
#
# Epoch 00042: val_loss improved from 0.24459 to 0.24232, saving model to ./model/42-0.2423.hdf5
#
# Epoch 00043: val_loss improved from 0.24232 to 0.24044, saving model to ./model/43-0.2404.hdf5
#
# Epoch 00044: val_loss improved from 0.24044 to 0.23847, saving model to ./model/44-0.2385.hdf5
#
# Epoch 00045: val_loss improved from 0.23847 to 0.23768, saving model to ./model/45-0.2377.hdf5
#
# Epoch 00046: val_loss improved from 0.23768 to 0.23749, saving model to ./model/46-0.2375.hdf5
#
# Epoch 00047: val_loss improved from 0.23749 to 0.23495, saving model to ./model/47-0.2350.hdf5
#
# Epoch 00048: val_loss improved from 0.23495 to 0.23219, saving model to ./model/48-0.2322.hdf5
#
# Epoch 00049: val_loss improved from 0.23219 to 0.23055, saving model to ./model/49-0.2305.hdf5
#
# Epoch 00050: val_loss improved from 0.23055 to 0.22975, saving model to ./model/50-0.2298.hdf5
#
# Epoch 00051: val_loss improved from 0.22975 to 0.22794, saving model to ./model/51-0.2279.hdf5
#
# Epoch 00052: val_loss improved from 0.22794 to 0.22669, saving model to ./model/52-0.2267.hdf5
#
# Epoch 00053: val_loss improved from 0.22669 to 0.22521, saving model to ./model/53-0.2252.hdf5
#
# Epoch 00054: val_loss improved from 0.22521 to 0.22442, saving model to ./model/54-0.2244.hdf5
#
# Epoch 00055: val_loss improved from 0.22442 to 0.22332, saving model to ./model/55-0.2233.hdf5
#
# Epoch 00056: val_loss improved from 0.22332 to 0.22152, saving model to ./model/56-0.2215.hdf5
#
# Epoch 00057: val_loss improved from 0.22152 to 0.22007, saving model to ./model/57-0.2201.hdf5
#
# Epoch 00058: val_loss improved from 0.22007 to 0.21860, saving model to ./model/58-0.2186.hdf5
#
# Epoch 00059: val_loss improved from 0.21860 to 0.21725, saving model to ./model/59-0.2172.hdf5
#
# Epoch 00060: val_loss improved from 0.21725 to 0.21692, saving model to ./model/60-0.2169.hdf5
#
# Epoch 00061: val_loss improved from 0.21692 to 0.21680, saving model to ./model/61-0.2168.hdf5
#
# Epoch 00062: val_loss improved from 0.21680 to 0.21335, saving model to ./model/62-0.2133.hdf5
#
# Epoch 00063: val_loss improved from 0.21335 to 0.21082, saving model to ./model/63-0.2108.hdf5
#
# Epoch 00064: val_loss improved from 0.21082 to 0.20927, saving model to ./model/64-0.2093.hdf5
#
# Epoch 00065: val_loss improved from 0.20927 to 0.20915, saving model to ./model/65-0.2092.hdf5
#
# Epoch 00066: val_loss improved from 0.20915 to 0.20830, saving model to ./model/66-0.2083.hdf5
#
# Epoch 00067: val_loss improved from 0.20830 to 0.20560, saving model to ./model/67-0.2056.hdf5
#
# Epoch 00068: val_loss improved from 0.20560 to 0.20478, saving model to ./model/68-0.2048.hdf5
#
# Epoch 00069: val_loss improved from 0.20478 to 0.20350, saving model to ./model/69-0.2035.hdf5
#
# Epoch 00070: val_loss did not improve from 0.20350
#
# Epoch 00071: val_loss did not improve from 0.20350
#
# Epoch 00072: val_loss improved from 0.20350 to 0.20200, saving model to ./model/72-0.2020.hdf5
#
# Epoch 00073: val_loss improved from 0.20200 to 0.19927, saving model to ./model/73-0.1993.hdf5
#
# Epoch 00074: val_loss improved from 0.19927 to 0.19813, saving model to ./model/74-0.1981.hdf5
#
# Epoch 00075: val_loss improved from 0.19813 to 0.19804, saving model to ./model/75-0.1980.hdf5
#
# Epoch 00076: val_loss did not improve from 0.19804
#
# Epoch 00077: val_loss improved from 0.19804 to 0.19741, saving model to ./model/77-0.1974.hdf5
#
# Epoch 00078: val_loss improved from 0.19741 to 0.19573, saving model to ./model/78-0.1957.hdf5
#
# Epoch 00079: val_loss improved from 0.19573 to 0.19309, saving model to ./model/79-0.1931.hdf5
#
# Epoch 00080: val_loss improved from 0.19309 to 0.19172, saving model to ./model/80-0.1917.hdf5
#
# Epoch 00081: val_loss did not improve from 0.19172
#
# Epoch 00082: val_loss did not improve from 0.19172
#
# Epoch 00083: val_loss improved from 0.19172 to 0.19149, saving model to ./model/83-0.1915.hdf5
#
# Epoch 00084: val_loss improved from 0.19149 to 0.18855, saving model to ./model/84-0.1885.hdf5
#
# Epoch 00085: val_loss improved from 0.18855 to 0.18771, saving model to ./model/85-0.1877.hdf5
#
# Epoch 00086: val_loss improved from 0.18771 to 0.18750, saving model to ./model/86-0.1875.hdf5
#
# Epoch 00087: val_loss did not improve from 0.18750
#
# Epoch 00088: val_loss did not improve from 0.18750
#
# Epoch 00089: val_loss improved from 0.18750 to 0.18679, saving model to ./model/89-0.1868.hdf5
#
# Epoch 00090: val_loss improved from 0.18679 to 0.18419, saving model to ./model/90-0.1842.hdf5
#
# Epoch 00091: val_loss improved from 0.18419 to 0.18290, saving model to ./model/91-0.1829.hdf5
# Epoch 00092: val_loss did not improve from 0.18290
#
# Epoch 00093: val_loss did not improve from 0.18290
#
# Epoch 00094: val_loss did not improve from 0.18290
#
# Epoch 00095: val_loss improved from 0.18290 to 0.18191, saving model to ./model/95-0.1819.hdf5
#
# Epoch 00096: val_loss improved from 0.18191 to 0.18100, saving model to ./model/96-0.1810.hdf5
#
# Epoch 00097: val_loss improved from 0.18100 to 0.18057, saving model to ./model/97-0.1806.hdf5
#
# Epoch 00098: val_loss improved from 0.18057 to 0.17963, saving model to ./model/98-0.1796.hdf5
#
# Epoch 00099: val_loss improved from 0.17963 to 0.17941, saving model to ./model/99-0.1794.hdf5
#
# Epoch 00100: val_loss improved from 0.17941 to 0.17785, saving model to ./model/100-0.1778.hdf5
#
# Epoch 00101: val_loss improved from 0.17785 to 0.17646, saving model to ./model/101-0.1765.hdf5
#
# Epoch 00102: val_loss improved from 0.17646 to 0.17464, saving model to ./model/102-0.1746.hdf5
#
# Epoch 00103: val_loss improved from 0.17464 to 0.17397, saving model to ./model/103-0.1740.hdf5
#
# Epoch 00104: val_loss did not improve from 0.17397
#
# Epoch 00105: val_loss did not improve from 0.17397
#
# Epoch 00106: val_loss did not improve from 0.17397
#
# Epoch 00107: val_loss improved from 0.17397 to 0.17049, saving model to ./model/107-0.1705.hdf5
#
# Epoch 00108: val_loss improved from 0.17049 to 0.16973, saving model to ./model/108-0.1697.hdf5
#
# Epoch 00109: val_loss did not improve from 0.16973
#
# Epoch 00110: val_loss did not improve from 0.16973
#
# Epoch 00111: val_loss did not improve from 0.16973
#
# Epoch 00112: val_loss improved from 0.16973 to 0.16707, saving model to ./model/112-0.1671.hdf5
#
# Epoch 00113: val_loss improved from 0.16707 to 0.16648, saving model to ./model/113-0.1665.hdf5
#
# Epoch 00114: val_loss did not improve from 0.16648
#
# Epoch 00115: val_loss did not improve from 0.16648
#
# Epoch 00116: val_loss did not improve from 0.16648
#
# Epoch 00117: val_loss improved from 0.16648 to 0.16503, saving model to ./model/117-0.1650.hdf5
#
# Epoch 00118: val_loss improved from 0.16503 to 0.16462, saving model to ./model/118-0.1646.hdf5
#
# Epoch 00119: val_loss did not improve from 0.16462
#
# Epoch 00120: val_loss did not improve from 0.16462
#
# Epoch 00121: val_loss improved from 0.16462 to 0.16404, saving model to ./model/121-0.1640.hdf5
#
# Epoch 00122: val_loss improved from 0.16404 to 0.16047, saving model to ./model/122-0.1605.hdf5
#
# Epoch 00123: val_loss did not improve from 0.16047
#
# Epoch 00124: val_loss did not improve from 0.16047
#
# Epoch 00125: val_loss did not improve from 0.16047
#
# Epoch 00126: val_loss did not improve from 0.16047
#
# Epoch 00127: val_loss improved from 0.16047 to 0.15829, saving model to ./model/127-0.1583.hdf5
#
# Epoch 00128: val_loss did not improve from 0.15829
#
# Epoch 00129: val_loss did not improve from 0.15829
#
# Epoch 00130: val_loss did not improve from 0.15829
#
# Epoch 00131: val_loss did not improve from 0.15829
#
# Epoch 00132: val_loss improved from 0.15829 to 0.15615, saving model to ./model/132-0.1561.hdf5
#
# Epoch 00133: val_loss improved from 0.15615 to 0.15542, saving model to ./model/133-0.1554.hdf5
#
# Epoch 00134: val_loss did not improve from 0.15542
#
# Epoch 00135: val_loss did not improve from 0.15542
#
# Epoch 00136: val_loss improved from 0.15542 to 0.15441, saving model to ./model/136-0.1544.hdf5
#
# Epoch 00137: val_loss improved from 0.15441 to 0.15356, saving model to ./model/137-0.1536.hdf5
#
# Epoch 00138: val_loss did not improve from 0.15356
#
# Epoch 00139: val_loss did not improve from 0.15356
#
# Epoch 00140: val_loss improved from 0.15356 to 0.15239, saving model to ./model/140-0.1524.hdf5
#
# Epoch 00141: val_loss improved from 0.15239 to 0.15135, saving model to ./model/141-0.1514.hdf5
#
# Epoch 00142: val_loss did not improve from 0.15135
#
# Epoch 00143: val_loss did not improve from 0.15135
#
# Epoch 00144: val_loss did not improve from 0.15135
#
# Epoch 00145: val_loss improved from 0.15135 to 0.14921, saving model to ./model/145-0.1492.hdf5
#
# Epoch 00146: val_loss improved from 0.14921 to 0.14886, saving model to ./model/146-0.1489.hdf5
#
# Epoch 00147: val_loss did not improve from 0.14886
#
# Epoch 00148: val_loss did not improve from 0.14886
#
# Epoch 00149: val_loss did not improve from 0.14886
#
# Epoch 00150: val_loss did not improve from 0.14886
#
# Epoch 00151: val_loss did not improve from 0.14886
#
# Epoch 00152: val_loss did not improve from 0.14886
#
# Epoch 00153: val_loss did not improve from 0.14886
#
# Epoch 00154: val_loss improved from 0.14886 to 0.14605, saving model to ./model/154-0.1461.hdf5
#
# Epoch 00155: val_loss improved from 0.14605 to 0.14427, saving model to ./model/155-0.1443.hdf5
#
# Epoch 00156: val_loss did not improve from 0.14427
#
# Epoch 00157: val_loss did not improve from 0.14427
#
# Epoch 00158: val_loss did not improve from 0.14427
#
# Epoch 00159: val_loss did not improve from 0.14427
#
# Epoch 00160: val_loss improved from 0.14427 to 0.14344, saving model to ./model/160-0.1434.hdf5
#
# Epoch 00161: val_loss did not improve from 0.14344
#
# Epoch 00162: val_loss did not improve from 0.14344
#
# Epoch 00163: val_loss improved from 0.14344 to 0.14275, saving model to ./model/163-0.1427.hdf5
#
# Epoch 00164: val_loss improved from 0.14275 to 0.14081, saving model to ./model/164-0.1408.hdf5
#
# Epoch 00165: val_loss did not improve from 0.14081
#
# Epoch 00166: val_loss did not improve from 0.14081
#
# Epoch 00167: val_loss did not improve from 0.14081
#
# Epoch 00168: val_loss improved from 0.14081 to 0.13946, saving model to ./model/168-0.1395.hdf5
#
# Epoch 00169: val_loss improved from 0.13946 to 0.13849, saving model to ./model/169-0.1385.hdf5
#
# Epoch 00170: val_loss did not improve from 0.13849
#
# Epoch 00171: val_loss did not improve from 0.13849
#
# Epoch 00172: val_loss did not improve from 0.13849
#
# Epoch 00173: val_loss did not improve from 0.13849
#
# Epoch 00174: val_loss did not improve from 0.13849
#
# Epoch 00175: val_loss did not improve from 0.13849
#
# Epoch 00176: val_loss improved from 0.13849 to 0.13530, saving model to ./model/176-0.1353.hdf5
#
# Epoch 00177: val_loss did not improve from 0.13530
#
# Epoch 00178: val_loss did not improve from 0.13530
#
# Epoch 00179: val_loss did not improve from 0.13530
#
# Epoch 00180: val_loss did not improve from 0.13530
#
# Epoch 00181: val_loss improved from 0.13530 to 0.13329, saving model to ./model/181-0.1333.hdf5
#
# Epoch 00182: val_loss did not improve from 0.13329
#
# Epoch 00183: val_loss did not improve from 0.13329
#
# Epoch 00184: val_loss did not improve from 0.13329
#
# Epoch 00185: val_loss did not improve from 0.13329
#
# Epoch 00186: val_loss improved from 0.13329 to 0.13259, saving model to ./model/186-0.1326.hdf5
#
# Epoch 00187: val_loss did not improve from 0.13259
#
# Epoch 00188: val_loss did not improve from 0.13259
#
# Epoch 00189: val_loss did not improve from 0.13259
#
# Epoch 00190: val_loss improved from 0.13259 to 0.13008, saving model to ./model/190-0.1301.hdf5
#
# Epoch 00191: val_loss did not improve from 0.13008
#
# Epoch 00192: val_loss did not improve from 0.13008
#
# Epoch 00193: val_loss did not improve from 0.13008
#
# Epoch 00194: val_loss improved from 0.13008 to 0.12902, saving model to ./model/194-0.1290.hdf5
#
# Epoch 00195: val_loss did not improve from 0.12902
#
# Epoch 00196: val_loss did not improve from 0.12902
#
# Epoch 00197: val_loss did not improve from 0.12902
#
# Epoch 00198: val_loss improved from 0.12902 to 0.12712, saving model to ./model/198-0.1271.hdf5
#
# Epoch 00199: val_loss did not improve from 0.12712
#
# Epoch 00200: val_loss did not improve from 0.12712
#
# Epoch 00201: val_loss did not improve from 0.12712
#
# Epoch 00202: val_loss improved from 0.12712 to 0.12588, saving model to ./model/202-0.1259.hdf5
#
# Epoch 00203: val_loss did not improve from 0.12588
#
# Epoch 00204: val_loss did not improve from 0.12588
#
# Epoch 00205: val_loss did not improve from 0.12588
#
# Epoch 00206: val_loss improved from 0.12588 to 0.12505, saving model to ./model/206-0.1251.hdf5
#
# Epoch 00207: val_loss did not improve from 0.12505
#
# Epoch 00208: val_loss did not improve from 0.12505
#
# Epoch 00209: val_loss did not improve from 0.12505
#
# Epoch 00210: val_loss did not improve from 0.12505
#
# Epoch 00211: val_loss improved from 0.12505 to 0.12394, saving model to ./model/211-0.1239.hdf5
#
# Epoch 00212: val_loss did not improve from 0.12394
#
# Epoch 00213: val_loss did not improve from 0.12394
#
# Epoch 00214: val_loss improved from 0.12394 to 0.12377, saving model to ./model/214-0.1238.hdf5
#
# Epoch 00215: val_loss improved from 0.12377 to 0.12234, saving model to ./model/215-0.1223.hdf5
#
# Epoch 00216: val_loss did not improve from 0.12234
#
# Epoch 00217: val_loss did not improve from 0.12234
#
# Epoch 00218: val_loss did not improve from 0.12234
#
# Epoch 00219: val_loss did not improve from 0.12234
#
# Epoch 00220: val_loss did not improve from 0.12234
#
# Epoch 00221: val_loss did not improve from 0.12234
#
# Epoch 00222: val_loss did not improve from 0.12234
#
# Epoch 00223: val_loss did not improve from 0.12234
#
# Epoch 00224: val_loss did not improve from 0.12234
#
# Epoch 00225: val_loss did not improve from 0.12234
#
# Epoch 00226: val_loss did not improve from 0.12234
#
# Epoch 00227: val_loss improved from 0.12234 to 0.12036, saving model to ./model/227-0.1204.hdf5
#
# Epoch 00228: val_loss did not improve from 0.12036
# Epoch 00229: val_loss did not improve from 0.12036
#
# Epoch 00230: val_loss improved from 0.12036 to 0.11901, saving model to ./model/230-0.1190.hdf5
#
# Epoch 00231: val_loss improved from 0.11901 to 0.11789, saving model to ./model/231-0.1179.hdf5
#
# Epoch 00232: val_loss did not improve from 0.11789
#
# Epoch 00233: val_loss did not improve from 0.11789
#
# Epoch 00234: val_loss improved from 0.11789 to 0.11685, saving model to ./model/234-0.1168.hdf5
#
# Epoch 00235: val_loss did not improve from 0.11685
#
# Epoch 00236: val_loss did not improve from 0.11685
#
# Epoch 00237: val_loss did not improve from 0.11685
#
# Epoch 00238: val_loss improved from 0.11685 to 0.11621, saving model to ./model/238-0.1162.hdf5
#
# Epoch 00239: val_loss did not improve from 0.11621
#
# Epoch 00240: val_loss did not improve from 0.11621
#
# Epoch 00241: val_loss did not improve from 0.11621
#
# Epoch 00242: val_loss improved from 0.11621 to 0.11384, saving model to ./model/242-0.1138.hdf5
#
# Epoch 00243: val_loss did not improve from 0.11384
#
# Epoch 00244: val_loss did not improve from 0.11384
#
# Epoch 00245: val_loss did not improve from 0.11384
#
# Epoch 00246: val_loss did not improve from 0.11384
#
# Epoch 00247: val_loss did not improve from 0.11384
#
# Epoch 00248: val_loss did not improve from 0.11384
#
# Epoch 00249: val_loss improved from 0.11384 to 0.11347, saving model to ./model/249-0.1135.hdf5
#
# Epoch 00250: val_loss improved from 0.11347 to 0.11160, saving model to ./model/250-0.1116.hdf5
#
# Epoch 00251: val_loss did not improve from 0.11160
#
# Epoch 00252: val_loss did not improve from 0.11160
#
# Epoch 00253: val_loss did not improve from 0.11160
#
# Epoch 00254: val_loss improved from 0.11160 to 0.11117, saving model to ./model/254-0.1112.hdf5
#
# Epoch 00255: val_loss did not improve from 0.11117
#
# Epoch 00256: val_loss did not improve from 0.11117
#
# Epoch 00257: val_loss did not improve from 0.11117
#
# Epoch 00258: val_loss improved from 0.11117 to 0.11027, saving model to ./model/258-0.1103.hdf5
#
# Epoch 00259: val_loss did not improve from 0.11027
#
# Epoch 00260: val_loss did not improve from 0.11027
#
# Epoch 00261: val_loss improved from 0.11027 to 0.10980, saving model to ./model/261-0.1098.hdf5
#
# Epoch 00262: val_loss improved from 0.10980 to 0.10916, saving model to ./model/262-0.1092.hdf5
#
# Epoch 00263: val_loss did not improve from 0.10916
#
# Epoch 00264: val_loss did not improve from 0.10916
#
# Epoch 00265: val_loss did not improve from 0.10916
#
# Epoch 00266: val_loss improved from 0.10916 to 0.10664, saving model to ./model/266-0.1066.hdf5
#
# Epoch 00267: val_loss did not improve from 0.10664
#
# Epoch 00268: val_loss did not improve from 0.10664
#
# Epoch 00269: val_loss did not improve from 0.10664
#
# Epoch 00270: val_loss improved from 0.10664 to 0.10658, saving model to ./model/270-0.1066.hdf5
#
# Epoch 00271: val_loss improved from 0.10658 to 0.10648, saving model to ./model/271-0.1065.hdf5
#
# Epoch 00272: val_loss did not improve from 0.10648
#
# Epoch 00273: val_loss did not improve from 0.10648
#
# Epoch 00274: val_loss did not improve from 0.10648
#
# Epoch 00275: val_loss did not improve from 0.10648
#
# Epoch 00276: val_loss did not improve from 0.10648
#
# Epoch 00277: val_loss did not improve from 0.10648
#
# Epoch 00278: val_loss did not improve from 0.10648
#
# Epoch 00279: val_loss improved from 0.10648 to 0.10533, saving model to ./model/279-0.1053.hdf5
#
# Epoch 00280: val_loss did not improve from 0.10533
#
# Epoch 00281: val_loss did not improve from 0.10533
#
# Epoch 00282: val_loss did not improve from 0.10533
#
# Epoch 00283: val_loss did not improve from 0.10533
#
# Epoch 00284: val_loss improved from 0.10533 to 0.10517, saving model to ./model/284-0.1052.hdf5
#
# Epoch 00285: val_loss did not improve from 0.10517
#
# Epoch 00286: val_loss did not improve from 0.10517
#
# Epoch 00287: val_loss improved from 0.10517 to 0.10320, saving model to ./model/287-0.1032.hdf5
#
# Epoch 00288: val_loss did not improve from 0.10320
#
# Epoch 00289: val_loss did not improve from 0.10320
#
# Epoch 00290: val_loss did not improve from 0.10320
#
# Epoch 00291: val_loss did not improve from 0.10320
#
# Epoch 00292: val_loss improved from 0.10320 to 0.10099, saving model to ./model/292-0.1010.hdf5
#
# Epoch 00293: val_loss did not improve from 0.10099
#
# Epoch 00294: val_loss did not improve from 0.10099
#
# Epoch 00295: val_loss did not improve from 0.10099
#
# Epoch 00296: val_loss did not improve from 0.10099
#
# Epoch 00297: val_loss did not improve from 0.10099
#
# Epoch 00298: val_loss did not improve from 0.10099
#
# Epoch 00299: val_loss improved from 0.10099 to 0.09785, saving model to ./model/299-0.0978.hdf5
#
# Epoch 00300: val_loss did not improve from 0.09785
#
# Epoch 00301: val_loss did not improve from 0.09785
#
# Epoch 00302: val_loss did not improve from 0.09785
#
# Epoch 00303: val_loss improved from 0.09785 to 0.09748, saving model to ./model/303-0.0975.hdf5
#
# Epoch 00304: val_loss did not improve from 0.09748
#
# Epoch 00305: val_loss did not improve from 0.09748
#
# Epoch 00306: val_loss improved from 0.09748 to 0.09645, saving model to ./model/306-0.0965.hdf5
#
# Epoch 00307: val_loss did not improve from 0.09645
#
# Epoch 00308: val_loss did not improve from 0.09645
#
# Epoch 00309: val_loss did not improve from 0.09645
#
# Epoch 00310: val_loss improved from 0.09645 to 0.09596, saving model to ./model/310-0.0960.hdf5
#
# Epoch 00311: val_loss did not improve from 0.09596
#
# Epoch 00312: val_loss did not improve from 0.09596
#
# Epoch 00313: val_loss did not improve from 0.09596
#
# Epoch 00314: val_loss did not improve from 0.09596
#
# Epoch 00315: val_loss did not improve from 0.09596
#
# Epoch 00316: val_loss did not improve from 0.09596
#
# Epoch 00317: val_loss did not improve from 0.09596
#
# Epoch 00318: val_loss did not improve from 0.09596
#
# Epoch 00319: val_loss did not improve from 0.09596
#
# Epoch 00320: val_loss improved from 0.09596 to 0.09488, saving model to ./model/320-0.0949.hdf5
#
# Epoch 00321: val_loss did not improve from 0.09488
#
# Epoch 00322: val_loss did not improve from 0.09488
#
# Epoch 00323: val_loss improved from 0.09488 to 0.09301, saving model to ./model/323-0.0930.hdf5
#
# Epoch 00324: val_loss did not improve from 0.09301
#
# Epoch 00325: val_loss did not improve from 0.09301
#
# Epoch 00326: val_loss did not improve from 0.09301
#
# Epoch 00327: val_loss did not improve from 0.09301
#
# Epoch 00328: val_loss did not improve from 0.09301
#
# Epoch 00329: val_loss did not improve from 0.09301
#
# Epoch 00330: val_loss improved from 0.09301 to 0.09113, saving model to ./model/330-0.0911.hdf5
#
# Epoch 00331: val_loss did not improve from 0.09113
#
# Epoch 00332: val_loss did not improve from 0.09113
#
# Epoch 00333: val_loss did not improve from 0.09113
#
# Epoch 00334: val_loss improved from 0.09113 to 0.09029, saving model to ./model/334-0.0903.hdf5
#
# Epoch 00335: val_loss did not improve from 0.09029
#
# Epoch 00336: val_loss did not improve from 0.09029
#
# Epoch 00337: val_loss improved from 0.09029 to 0.08891, saving model to ./model/337-0.0889.hdf5
#
# Epoch 00338: val_loss did not improve from 0.08891
#
# Epoch 00339: val_loss did not improve from 0.08891
#
# Epoch 00340: val_loss did not improve from 0.08891
#
# Epoch 00341: val_loss did not improve from 0.08891
#
# Epoch 00342: val_loss did not improve from 0.08891
#
# Epoch 00343: val_loss did not improve from 0.08891
#
# Epoch 00344: val_loss did not improve from 0.08891
#
# Epoch 00345: val_loss improved from 0.08891 to 0.08888, saving model to ./model/345-0.0889.hdf5
#
# Epoch 00346: val_loss did not improve from 0.08888
#
# Epoch 00347: val_loss did not improve from 0.08888
#
# Epoch 00348: val_loss improved from 0.08888 to 0.08887, saving model to ./model/348-0.0889.hdf5
#
# Epoch 00349: val_loss did not improve from 0.08887
#
# Epoch 00350: val_loss did not improve from 0.08887
#
# Epoch 00351: val_loss did not improve from 0.08887
#
# Epoch 00352: val_loss did not improve from 0.08887
#
# Epoch 00353: val_loss did not improve from 0.08887
#
# Epoch 00354: val_loss did not improve from 0.08887
#
# Epoch 00355: val_loss improved from 0.08887 to 0.08748, saving model to ./model/355-0.0875.hdf5
#
# Epoch 00356: val_loss improved from 0.08748 to 0.08627, saving model to ./model/356-0.0863.hdf5
#
# Epoch 00357: val_loss did not improve from 0.08627
#
# Epoch 00358: val_loss did not improve from 0.08627
#
# Epoch 00359: val_loss did not improve from 0.08627
#
# Epoch 00360: val_loss did not improve from 0.08627
#
# Epoch 00361: val_loss did not improve from 0.08627
#
# Epoch 00362: val_loss improved from 0.08627 to 0.08496, saving model to ./model/362-0.0850.hdf5
#
# Epoch 00363: val_loss did not improve from 0.08496
#
# Epoch 00364: val_loss did not improve from 0.08496
#
# Epoch 00365: val_loss did not improve from 0.08496
#
# Epoch 00366: val_loss did not improve from 0.08496
#
# Epoch 00367: val_loss improved from 0.08496 to 0.08470, saving model to ./model/367-0.0847.hdf5
#
# Epoch 00368: val_loss did not improve from 0.08470
#
# Epoch 00369: val_loss did not improve from 0.08470
#
# Epoch 00370: val_loss improved from 0.08470 to 0.08214, saving model to ./model/370-0.0821.hdf5
#
# Epoch 00371: val_loss did not improve from 0.08214
#
# Epoch 00372: val_loss did not improve from 0.08214
#
# Epoch 00373: val_loss did not improve from 0.08214
#
# Epoch 00374: val_loss improved from 0.08214 to 0.08073, saving model to ./model/374-0.0807.hdf5
#
# Epoch 00375: val_loss did not improve from 0.08073
#
# Epoch 00376: val_loss did not improve from 0.08073
#
# Epoch 00377: val_loss did not improve from 0.08073
#
# Epoch 00378: val_loss improved from 0.08073 to 0.08014, saving model to ./model/378-0.0801.hdf5
#
# Epoch 00379: val_loss did not improve from 0.08014
#
# Epoch 00380: val_loss did not improve from 0.08014
#
# Epoch 00381: val_loss did not improve from 0.08014
#
# Epoch 00382: val_loss improved from 0.08014 to 0.07998, saving model to ./model/382-0.0800.hdf5
#
# Epoch 00383: val_loss did not improve from 0.07998
# Epoch 00384: val_loss did not improve from 0.07998
#
# Epoch 00385: val_loss did not improve from 0.07998
#
# Epoch 00386: val_loss improved from 0.07998 to 0.07903, saving model to ./model/386-0.0790.hdf5
#
# Epoch 00387: val_loss did not improve from 0.07903
#
# Epoch 00388: val_loss did not improve from 0.07903
#
# Epoch 00389: val_loss did not improve from 0.07903
#
# Epoch 00390: val_loss improved from 0.07903 to 0.07807, saving model to ./model/390-0.0781.hdf5
#
# Epoch 00391: val_loss did not improve from 0.07807
#
# Epoch 00392: val_loss did not improve from 0.07807
#
# Epoch 00393: val_loss did not improve from 0.07807
#
# Epoch 00394: val_loss did not improve from 0.07807
#
# Epoch 00395: val_loss did not improve from 0.07807
#
# Epoch 00396: val_loss did not improve from 0.07807
#
# Epoch 00397: val_loss improved from 0.07807 to 0.07596, saving model to ./model/397-0.0760.hdf5
#
# Epoch 00398: val_loss did not improve from 0.07596
#
# Epoch 00399: val_loss did not improve from 0.07596
#
# Epoch 00400: val_loss did not improve from 0.07596
#
# Epoch 00401: val_loss did not improve from 0.07596
#
# Epoch 00402: val_loss did not improve from 0.07596
#
# Epoch 00403: val_loss improved from 0.07596 to 0.07536, saving model to ./model/403-0.0754.hdf5
#
# Epoch 00404: val_loss did not improve from 0.07536
#
# Epoch 00405: val_loss did not improve from 0.07536
#
# Epoch 00406: val_loss did not improve from 0.07536
#
# Epoch 00407: val_loss improved from 0.07536 to 0.07385, saving model to ./model/407-0.0739.hdf5
#
# Epoch 00408: val_loss did not improve from 0.07385
#
# Epoch 00409: val_loss did not improve from 0.07385
#
# Epoch 00410: val_loss did not improve from 0.07385
#
# Epoch 00411: val_loss did not improve from 0.07385
#
# Epoch 00412: val_loss did not improve from 0.07385
#
# Epoch 00413: val_loss did not improve from 0.07385
#
# Epoch 00414: val_loss did not improve from 0.07385
#
# Epoch 00415: val_loss did not improve from 0.07385
#
# Epoch 00416: val_loss did not improve from 0.07385
#
# Epoch 00417: val_loss did not improve from 0.07385
#
# Epoch 00418: val_loss improved from 0.07385 to 0.07304, saving model to ./model/418-0.0730.hdf5
#
# Epoch 00419: val_loss did not improve from 0.07304
#
# Epoch 00420: val_loss did not improve from 0.07304
#
# Epoch 00421: val_loss improved from 0.07304 to 0.07048, saving model to ./model/421-0.0705.hdf5
#
# Epoch 00422: val_loss did not improve from 0.07048
#
# Epoch 00423: val_loss did not improve from 0.07048
#
# Epoch 00424: val_loss did not improve from 0.07048
#
# Epoch 00425: val_loss improved from 0.07048 to 0.06950, saving model to ./model/425-0.0695.hdf5
#
# Epoch 00426: val_loss did not improve from 0.06950
#
# Epoch 00427: val_loss did not improve from 0.06950
#
# Epoch 00428: val_loss did not improve from 0.06950
#
# Epoch 00429: val_loss improved from 0.06950 to 0.06907, saving model to ./model/429-0.0691.hdf5
#
# Epoch 00430: val_loss did not improve from 0.06907
#
# Epoch 00431: val_loss did not improve from 0.06907
#
# Epoch 00432: val_loss improved from 0.06907 to 0.06882, saving model to ./model/432-0.0688.hdf5
#
# Epoch 00433: val_loss did not improve from 0.06882
#
# Epoch 00434: val_loss did not improve from 0.06882
#
# Epoch 00435: val_loss did not improve from 0.06882
#
# Epoch 00436: val_loss did not improve from 0.06882
#
# Epoch 00437: val_loss did not improve from 0.06882
#
# Epoch 00438: val_loss did not improve from 0.06882
#
# Epoch 00439: val_loss improved from 0.06882 to 0.06861, saving model to ./model/439-0.0686.hdf5
#
# Epoch 00440: val_loss did not improve from 0.06861
#
# Epoch 00441: val_loss did not improve from 0.06861
#
# Epoch 00442: val_loss did not improve from 0.06861
#
# Epoch 00443: val_loss did not improve from 0.06861
#
# Epoch 00444: val_loss did not improve from 0.06861
#
# Epoch 00445: val_loss did not improve from 0.06861
#
# Epoch 00446: val_loss did not improve from 0.06861
#
# Epoch 00447: val_loss did not improve from 0.06861
#
# Epoch 00448: val_loss improved from 0.06861 to 0.06622, saving model to ./model/448-0.0662.hdf5
#
# Epoch 00449: val_loss did not improve from 0.06622
#
# Epoch 00450: val_loss did not improve from 0.06622
#
# Epoch 00451: val_loss did not improve from 0.06622
#
# Epoch 00452: val_loss improved from 0.06622 to 0.06609, saving model to ./model/452-0.0661.hdf5
#
# Epoch 00453: val_loss did not improve from 0.06609
#
# Epoch 00454: val_loss did not improve from 0.06609
#
# Epoch 00455: val_loss did not improve from 0.06609
#
# Epoch 00456: val_loss did not improve from 0.06609
#
# Epoch 00457: val_loss did not improve from 0.06609
#
# Epoch 00458: val_loss did not improve from 0.06609
#
# Epoch 00459: val_loss improved from 0.06609 to 0.06468, saving model to ./model/459-0.0647.hdf5
#
# Epoch 00460: val_loss did not improve from 0.06468
#
# Epoch 00461: val_loss did not improve from 0.06468
#
# Epoch 00462: val_loss did not improve from 0.06468
#
# Epoch 00463: val_loss did not improve from 0.06468
#
# Epoch 00464: val_loss did not improve from 0.06468
#
# Epoch 00465: val_loss did not improve from 0.06468
#
# Epoch 00466: val_loss did not improve from 0.06468
#
# Epoch 00467: val_loss did not improve from 0.06468
#
# Epoch 00468: val_loss did not improve from 0.06468
#
# Epoch 00469: val_loss did not improve from 0.06468
#
# Epoch 00470: val_loss did not improve from 0.06468
#
# Epoch 00471: val_loss did not improve from 0.06468
#
# Epoch 00472: val_loss improved from 0.06468 to 0.06437, saving model to ./model/472-0.0644.hdf5
#
# Epoch 00473: val_loss did not improve from 0.06437
#
# Epoch 00474: val_loss did not improve from 0.06437
#
# Epoch 00475: val_loss improved from 0.06437 to 0.06215, saving model to ./model/475-0.0622.hdf5
#
# Epoch 00476: val_loss did not improve from 0.06215
#
# Epoch 00477: val_loss did not improve from 0.06215
#
# Epoch 00478: val_loss did not improve from 0.06215
#
# Epoch 00479: val_loss did not improve from 0.06215
#
# Epoch 00480: val_loss did not improve from 0.06215
#
# Epoch 00481: val_loss did not improve from 0.06215
#
# Epoch 00482: val_loss did not improve from 0.06215
#
# Epoch 00483: val_loss did not improve from 0.06215
#
# Epoch 00484: val_loss did not improve from 0.06215
#
# Epoch 00485: val_loss did not improve from 0.06215
#
# Epoch 00486: val_loss did not improve from 0.06215
#
# Epoch 00487: val_loss did not improve from 0.06215
#
# Epoch 00488: val_loss did not improve from 0.06215
#
# Epoch 00489: val_loss did not improve from 0.06215
#
# Epoch 00490: val_loss did not improve from 0.06215
#
# Epoch 00491: val_loss did not improve from 0.06215
#
# Epoch 00492: val_loss did not improve from 0.06215
#
# Epoch 00493: val_loss did not improve from 0.06215
#
# Epoch 00494: val_loss did not improve from 0.06215
#
# Epoch 00495: val_loss improved from 0.06215 to 0.06102, saving model to ./model/495-0.0610.hdf5
#
# Epoch 00496: val_loss did not improve from 0.06102
#
# Epoch 00497: val_loss did not improve from 0.06102
#
# Epoch 00498: val_loss improved from 0.06102 to 0.05956, saving model to ./model/498-0.0596.hdf5
#
# Epoch 00499: val_loss did not improve from 0.05956
#
# Epoch 00500: val_loss did not improve from 0.05956
#
# Epoch 00501: val_loss did not improve from 0.05956
#
# Epoch 00502: val_loss improved from 0.05956 to 0.05879, saving model to ./model/502-0.0588.hdf5
#
# Epoch 00503: val_loss did not improve from 0.05879
#
# Epoch 00504: val_loss did not improve from 0.05879
#
# Epoch 00505: val_loss did not improve from 0.05879
#
# Epoch 00506: val_loss did not improve from 0.05879
#
# Epoch 00507: val_loss did not improve from 0.05879
#
# Epoch 00508: val_loss did not improve from 0.05879
#
# Epoch 00509: val_loss improved from 0.05879 to 0.05879, saving model to ./model/509-0.0588.hdf5
#
# Epoch 00510: val_loss did not improve from 0.05879
#
# Epoch 00511: val_loss did not improve from 0.05879
#
# Epoch 00512: val_loss did not improve from 0.05879
#
# Epoch 00513: val_loss improved from 0.05879 to 0.05869, saving model to ./model/513-0.0587.hdf5
#
# Epoch 00514: val_loss did not improve from 0.05869
#
# Epoch 00515: val_loss did not improve from 0.05869
#
# Epoch 00516: val_loss improved from 0.05869 to 0.05836, saving model to ./model/516-0.0584.hdf5
#
# Epoch 00517: val_loss did not improve from 0.05836
#
# Epoch 00518: val_loss did not improve from 0.05836
#
# Epoch 00519: val_loss did not improve from 0.05836
#
# Epoch 00520: val_loss did not improve from 0.05836
#
# Epoch 00521: val_loss did not improve from 0.05836
#
# Epoch 00522: val_loss did not improve from 0.05836
#
# Epoch 00523: val_loss improved from 0.05836 to 0.05690, saving model to ./model/523-0.0569.hdf5
#
# Epoch 00524: val_loss did not improve from 0.05690
#
# Epoch 00525: val_loss did not improve from 0.05690
#
# Epoch 00526: val_loss did not improve from 0.05690
#
# Epoch 00527: val_loss improved from 0.05690 to 0.05688, saving model to ./model/527-0.0569.hdf5
#
# Epoch 00528: val_loss did not improve from 0.05688
#
# Epoch 00529: val_loss did not improve from 0.05688
#
# Epoch 00530: val_loss improved from 0.05688 to 0.05656, saving model to ./model/530-0.0566.hdf5
#
# Epoch 00531: val_loss did not improve from 0.05656
#
# Epoch 00532: val_loss did not improve from 0.05656
#
# Epoch 00533: val_loss did not improve from 0.05656
#
# Epoch 00534: val_loss did not improve from 0.05656
#
# Epoch 00535: val_loss did not improve from 0.05656
# Epoch 00536: val_loss did not improve from 0.05656
#
# Epoch 00537: val_loss did not improve from 0.05656
#
# Epoch 00538: val_loss did not improve from 0.05656
#
# Epoch 00539: val_loss did not improve from 0.05656
#
# Epoch 00540: val_loss did not improve from 0.05656
#
# Epoch 00541: val_loss did not improve from 0.05656
#
# Epoch 00542: val_loss did not improve from 0.05656
#
# Epoch 00543: val_loss improved from 0.05656 to 0.05576, saving model to ./model/543-0.0558.hdf5
#
# Epoch 00544: val_loss did not improve from 0.05576
#
# Epoch 00545: val_loss did not improve from 0.05576
#
# Epoch 00546: val_loss did not improve from 0.05576
#
# Epoch 00547: val_loss improved from 0.05576 to 0.05540, saving model to ./model/547-0.0554.hdf5
#
# Epoch 00548: val_loss did not improve from 0.05540
#
# Epoch 00549: val_loss did not improve from 0.05540
#
# Epoch 00550: val_loss did not improve from 0.05540
#
# Epoch 00551: val_loss did not improve from 0.05540
#
# Epoch 00552: val_loss did not improve from 0.05540
#
# Epoch 00553: val_loss did not improve from 0.05540
#
# Epoch 00554: val_loss did not improve from 0.05540
#
# Epoch 00555: val_loss did not improve from 0.05540
#
# Epoch 00556: val_loss did not improve from 0.05540
#
# Epoch 00557: val_loss did not improve from 0.05540
#
# Epoch 00558: val_loss did not improve from 0.05540
#
# Epoch 00559: val_loss did not improve from 0.05540
#
# Epoch 00560: val_loss did not improve from 0.05540
#
# Epoch 00561: val_loss did not improve from 0.05540
#
# Epoch 00562: val_loss did not improve from 0.05540
#
# Epoch 00563: val_loss did not improve from 0.05540
#
# Epoch 00564: val_loss did not improve from 0.05540
#
# Epoch 00565: val_loss improved from 0.05540 to 0.05508, saving model to ./model/565-0.0551.hdf5
#
# Epoch 00566: val_loss did not improve from 0.05508
#
# Epoch 00567: val_loss did not improve from 0.05508
#
# Epoch 00568: val_loss did not improve from 0.05508
#
# Epoch 00569: val_loss did not improve from 0.05508
#
# Epoch 00570: val_loss did not improve from 0.05508
#
# Epoch 00571: val_loss did not improve from 0.05508
#
# Epoch 00572: val_loss did not improve from 0.05508
#
# Epoch 00573: val_loss did not improve from 0.05508
#
# Epoch 00574: val_loss improved from 0.05508 to 0.05444, saving model to ./model/574-0.0544.hdf5
#
# Epoch 00575: val_loss did not improve from 0.05444
#
# Epoch 00576: val_loss did not improve from 0.05444
#
# Epoch 00577: val_loss improved from 0.05444 to 0.05410, saving model to ./model/577-0.0541.hdf5
#
# Epoch 00578: val_loss did not improve from 0.05410
#
# Epoch 00579: val_loss did not improve from 0.05410
#
# Epoch 00580: val_loss improved from 0.05410 to 0.05248, saving model to ./model/580-0.0525.hdf5
#
# Epoch 00581: val_loss did not improve from 0.05248
#
# Epoch 00582: val_loss did not improve from 0.05248
#
# Epoch 00583: val_loss did not improve from 0.05248
#
# Epoch 00584: val_loss did not improve from 0.05248
#
# Epoch 00585: val_loss did not improve from 0.05248
#
# Epoch 00586: val_loss did not improve from 0.05248
#
# Epoch 00587: val_loss did not improve from 0.05248
#
# Epoch 00588: val_loss did not improve from 0.05248
#
# Epoch 00589: val_loss did not improve from 0.05248
#
# Epoch 00590: val_loss did not improve from 0.05248
#
# Epoch 00591: val_loss did not improve from 0.05248
#
# Epoch 00592: val_loss did not improve from 0.05248
#
# Epoch 00593: val_loss did not improve from 0.05248
#
# Epoch 00594: val_loss did not improve from 0.05248
#
# Epoch 00595: val_loss did not improve from 0.05248
#
# Epoch 00596: val_loss did not improve from 0.05248
#
# Epoch 00597: val_loss did not improve from 0.05248
#
# Epoch 00598: val_loss improved from 0.05248 to 0.05092, saving model to ./model/598-0.0509.hdf5
#
# Epoch 00599: val_loss improved from 0.05092 to 0.05083, saving model to ./model/599-0.0508.hdf5
#
# Epoch 00600: val_loss did not improve from 0.05083
#
# Epoch 00601: val_loss did not improve from 0.05083
#
# Epoch 00602: val_loss did not improve from 0.05083
#
# Epoch 00603: val_loss did not improve from 0.05083
#
# Epoch 00604: val_loss did not improve from 0.05083
#
# Epoch 00605: val_loss did not improve from 0.05083
#
# Epoch 00606: val_loss did not improve from 0.05083
#
# Epoch 00607: val_loss did not improve from 0.05083
#
# Epoch 00608: val_loss did not improve from 0.05083
#
# Epoch 00609: val_loss did not improve from 0.05083
#
# Epoch 00610: val_loss did not improve from 0.05083
#
# Epoch 00611: val_loss improved from 0.05083 to 0.04954, saving model to ./model/611-0.0495.hdf5
#
# Epoch 00612: val_loss did not improve from 0.04954
#
# Epoch 00613: val_loss did not improve from 0.04954
#
# Epoch 00614: val_loss improved from 0.04954 to 0.04943, saving model to ./model/614-0.0494.hdf5
#
# Epoch 00615: val_loss did not improve from 0.04943
#
# Epoch 00616: val_loss did not improve from 0.04943
#
# Epoch 00617: val_loss did not improve from 0.04943
#
# Epoch 00618: val_loss did not improve from 0.04943
#
# Epoch 00619: val_loss did not improve from 0.04943
#
# Epoch 00620: val_loss did not improve from 0.04943
#
# Epoch 00621: val_loss did not improve from 0.04943
#
# Epoch 00622: val_loss did not improve from 0.04943
#
# Epoch 00623: val_loss did not improve from 0.04943
#
# Epoch 00624: val_loss did not improve from 0.04943
#
# Epoch 00625: val_loss improved from 0.04943 to 0.04859, saving model to ./model/625-0.0486.hdf5
#
# Epoch 00626: val_loss did not improve from 0.04859
#
# Epoch 00627: val_loss did not improve from 0.04859
#
# Epoch 00628: val_loss improved from 0.04859 to 0.04806, saving model to ./model/628-0.0481.hdf5
#
# Epoch 00629: val_loss did not improve from 0.04806
#
# Epoch 00630: val_loss did not improve from 0.04806
#
# Epoch 00631: val_loss did not improve from 0.04806
#
# Epoch 00632: val_loss did not improve from 0.04806
#
# Epoch 00633: val_loss did not improve from 0.04806
#
# Epoch 00634: val_loss did not improve from 0.04806
#
# Epoch 00635: val_loss did not improve from 0.04806
#
# Epoch 00636: val_loss did not improve from 0.04806
#
# Epoch 00637: val_loss did not improve from 0.04806
#
# Epoch 00638: val_loss did not improve from 0.04806
#
# Epoch 00639: val_loss did not improve from 0.04806
#
# Epoch 00640: val_loss did not improve from 0.04806
#
# Epoch 00641: val_loss did not improve from 0.04806
#
# Epoch 00642: val_loss did not improve from 0.04806
#
# Epoch 00643: val_loss did not improve from 0.04806
#
# Epoch 00644: val_loss did not improve from 0.04806
#
# Epoch 00645: val_loss improved from 0.04806 to 0.04699, saving model to ./model/645-0.0470.hdf5
#
# Epoch 00646: val_loss did not improve from 0.04699
#
# Epoch 00647: val_loss did not improve from 0.04699
#
# Epoch 00648: val_loss did not improve from 0.04699
#
# Epoch 00649: val_loss did not improve from 0.04699
#
# Epoch 00650: val_loss did not improve from 0.04699
#
# Epoch 00651: val_loss did not improve from 0.04699
#
# Epoch 00652: val_loss did not improve from 0.04699
#
# Epoch 00653: val_loss did not improve from 0.04699
#
# Epoch 00654: val_loss did not improve from 0.04699
#
# Epoch 00655: val_loss did not improve from 0.04699
#
# Epoch 00656: val_loss improved from 0.04699 to 0.04697, saving model to ./model/656-0.0470.hdf5
#
# Epoch 00657: val_loss did not improve from 0.04697
#
# Epoch 00658: val_loss did not improve from 0.04697
#
# Epoch 00659: val_loss did not improve from 0.04697
#
# Epoch 00660: val_loss did not improve from 0.04697
#
# Epoch 00661: val_loss did not improve from 0.04697
#
# Epoch 00662: val_loss improved from 0.04697 to 0.04662, saving model to ./model/662-0.0466.hdf5
#
# Epoch 00663: val_loss did not improve from 0.04662
#
# Epoch 00664: val_loss did not improve from 0.04662
#
# Epoch 00665: val_loss improved from 0.04662 to 0.04644, saving model to ./model/665-0.0464.hdf5
#
# Epoch 00666: val_loss did not improve from 0.04644
#
# Epoch 00667: val_loss did not improve from 0.04644
#
# Epoch 00668: val_loss improved from 0.04644 to 0.04630, saving model to ./model/668-0.0463.hdf5
#
# Epoch 00669: val_loss improved from 0.04630 to 0.04516, saving model to ./model/669-0.0452.hdf5
#
# Epoch 00670: val_loss did not improve from 0.04516
#
# Epoch 00671: val_loss improved from 0.04516 to 0.04465, saving model to ./model/671-0.0446.hdf5
#
# Epoch 00672: val_loss did not improve from 0.04465
#
# Epoch 00673: val_loss did not improve from 0.04465
#
# Epoch 00674: val_loss did not improve from 0.04465
#
# Epoch 00675: val_loss did not improve from 0.04465
#
# Epoch 00676: val_loss did not improve from 0.04465
#
# Epoch 00677: val_loss improved from 0.04465 to 0.04454, saving model to ./model/677-0.0445.hdf5
#
# Epoch 00678: val_loss did not improve from 0.04454
#
# Epoch 00679: val_loss did not improve from 0.04454
#
# Epoch 00680: val_loss did not improve from 0.04454
#
# Epoch 00681: val_loss did not improve from 0.04454
#
# Epoch 00682: val_loss did not improve from 0.04454
#
# Epoch 00683: val_loss improved from 0.04454 to 0.04429, saving model to ./model/683-0.0443.hdf5
#
# Epoch 00684: val_loss improved from 0.04429 to 0.04407, saving model to ./model/684-0.0441.hdf5
#
# Epoch 00685: val_loss did not improve from 0.04407
#
# Epoch 00686: val_loss did not improve from 0.04407
# Epoch 00687: val_loss did not improve from 0.04407
#
# Epoch 00688: val_loss did not improve from 0.04407
#
# Epoch 00689: val_loss did not improve from 0.04407
#
# Epoch 00690: val_loss did not improve from 0.04407
#
# Epoch 00691: val_loss did not improve from 0.04407
#
# Epoch 00692: val_loss did not improve from 0.04407
#
# Epoch 00693: val_loss did not improve from 0.04407
#
# Epoch 00694: val_loss improved from 0.04407 to 0.04326, saving model to ./model/694-0.0433.hdf5
#
# Epoch 00695: val_loss improved from 0.04326 to 0.04321, saving model to ./model/695-0.0432.hdf5
#
# Epoch 00696: val_loss did not improve from 0.04321
#
# Epoch 00697: val_loss did not improve from 0.04321
#
# Epoch 00698: val_loss improved from 0.04321 to 0.04206, saving model to ./model/698-0.0421.hdf5
#
# Epoch 00699: val_loss improved from 0.04206 to 0.04148, saving model to ./model/699-0.0415.hdf5
#
# Epoch 00700: val_loss improved from 0.04148 to 0.04141, saving model to ./model/700-0.0414.hdf5
#
# Epoch 00701: val_loss improved from 0.04141 to 0.04074, saving model to ./model/701-0.0407.hdf5
#
# Epoch 00702: val_loss improved from 0.04074 to 0.03953, saving model to ./model/702-0.0395.hdf5
#
# Epoch 00703: val_loss improved from 0.03953 to 0.03889, saving model to ./model/703-0.0389.hdf5
#
# Epoch 00704: val_loss did not improve from 0.03889
#
# Epoch 00705: val_loss improved from 0.03889 to 0.03801, saving model to ./model/705-0.0380.hdf5
#
# Epoch 00706: val_loss did not improve from 0.03801
#
# Epoch 00707: val_loss did not improve from 0.03801
#
# Epoch 00708: val_loss did not improve from 0.03801
#
# Epoch 00709: val_loss did not improve from 0.03801
#
# Epoch 00710: val_loss did not improve from 0.03801
#
# Epoch 00711: val_loss did not improve from 0.03801
#
# Epoch 00712: val_loss did not improve from 0.03801
#
# Epoch 00713: val_loss did not improve from 0.03801
#
# Epoch 00714: val_loss did not improve from 0.03801
#
# Epoch 00715: val_loss did not improve from 0.03801
#
# Epoch 00716: val_loss did not improve from 0.03801
#
# Epoch 00717: val_loss did not improve from 0.03801
#
# Epoch 00718: val_loss did not improve from 0.03801
#
# Epoch 00719: val_loss did not improve from 0.03801
#
# Epoch 00720: val_loss did not improve from 0.03801
#
# Epoch 00721: val_loss did not improve from 0.03801
#
# Epoch 00722: val_loss did not improve from 0.03801
#
# Epoch 00723: val_loss did not improve from 0.03801
#
# Epoch 00724: val_loss did not improve from 0.03801
#
# Epoch 00725: val_loss did not improve from 0.03801
#
# Epoch 00726: val_loss did not improve from 0.03801
#
# Epoch 00727: val_loss did not improve from 0.03801
#
# Epoch 00728: val_loss did not improve from 0.03801
#
# Epoch 00729: val_loss did not improve from 0.03801
#
# Epoch 00730: val_loss did not improve from 0.03801
#
# Epoch 00731: val_loss did not improve from 0.03801
#
# Epoch 00732: val_loss did not improve from 0.03801
#
# Epoch 00733: val_loss did not improve from 0.03801
#
# Epoch 00734: val_loss did not improve from 0.03801
#
# Epoch 00735: val_loss did not improve from 0.03801
#
# Epoch 00736: val_loss did not improve from 0.03801
#
# Epoch 00737: val_loss did not improve from 0.03801
#
# Epoch 00738: val_loss did not improve from 0.03801
#
# Epoch 00739: val_loss did not improve from 0.03801
#
# Epoch 00740: val_loss did not improve from 0.03801
#
# Epoch 00741: val_loss did not improve from 0.03801
#
# Epoch 00742: val_loss did not improve from 0.03801
#
# Epoch 00743: val_loss did not improve from 0.03801
#
# Epoch 00744: val_loss did not improve from 0.03801
#
# Epoch 00745: val_loss did not improve from 0.03801
#
# Epoch 00746: val_loss did not improve from 0.03801
#
# Epoch 00747: val_loss did not improve from 0.03801
#
# Epoch 00748: val_loss did not improve from 0.03801
#
# Epoch 00749: val_loss did not improve from 0.03801
#
# Epoch 00750: val_loss did not improve from 0.03801
#
# Epoch 00751: val_loss did not improve from 0.03801
#
# Epoch 00752: val_loss did not improve from 0.03801
#
# Epoch 00753: val_loss did not improve from 0.03801
#
# Epoch 00754: val_loss did not improve from 0.03801
#
# Epoch 00755: val_loss did not improve from 0.03801
#
# Epoch 00756: val_loss did not improve from 0.03801
#
# Epoch 00757: val_loss did not improve from 0.03801
#
# Epoch 00758: val_loss did not improve from 0.03801
#
# Epoch 00759: val_loss did not improve from 0.03801
#
# Epoch 00760: val_loss did not improve from 0.03801
#
# Epoch 00761: val_loss did not improve from 0.03801
#
# Epoch 00762: val_loss did not improve from 0.03801
#
# Epoch 00763: val_loss did not improve from 0.03801
#
# Epoch 00764: val_loss did not improve from 0.03801
#
# Epoch 00765: val_loss did not improve from 0.03801
#
# Epoch 00766: val_loss did not improve from 0.03801
#
# Epoch 00767: val_loss did not improve from 0.03801
#
# Epoch 00768: val_loss did not improve from 0.03801
#
# Epoch 00769: val_loss did not improve from 0.03801
#
# Epoch 00770: val_loss did not improve from 0.03801
#
# Epoch 00771: val_loss did not improve from 0.03801
#
# Epoch 00772: val_loss did not improve from 0.03801
#
# Epoch 00773: val_loss did not improve from 0.03801
#
# Epoch 00774: val_loss did not improve from 0.03801
#
# Epoch 00775: val_loss did not improve from 0.03801
#
# Epoch 00776: val_loss did not improve from 0.03801
#
# Epoch 00777: val_loss did not improve from 0.03801
#
# Epoch 00778: val_loss did not improve from 0.03801
#
# Epoch 00779: val_loss did not improve from 0.03801
#
# Epoch 00780: val_loss did not improve from 0.03801
#
# Epoch 00781: val_loss did not improve from 0.03801
#
# Epoch 00782: val_loss did not improve from 0.03801
#
# Epoch 00783: val_loss did not improve from 0.03801
#
# Epoch 00784: val_loss did not improve from 0.03801
#
# Epoch 00785: val_loss did not improve from 0.03801
#
# Epoch 00786: val_loss did not improve from 0.03801
#
# Epoch 00787: val_loss did not improve from 0.03801
#
# Epoch 00788: val_loss did not improve from 0.03801
#
# Epoch 00789: val_loss did not improve from 0.03801
#
# Epoch 00790: val_loss did not improve from 0.03801
#
# Epoch 00791: val_loss did not improve from 0.03801
#
# Epoch 00792: val_loss did not improve from 0.03801
#
# Epoch 00793: val_loss did not improve from 0.03801
#
# Epoch 00794: val_loss did not improve from 0.03801
#
# Epoch 00795: val_loss did not improve from 0.03801
#
# Epoch 00796: val_loss did not improve from 0.03801
#
# Epoch 00797: val_loss did not improve from 0.03801
#
# Epoch 00798: val_loss did not improve from 0.03801
#
# Epoch 00799: val_loss did not improve from 0.03801
#
# Epoch 00800: val_loss did not improve from 0.03801
#
# Epoch 00801: val_loss did not improve from 0.03801
#
# Epoch 00802: val_loss did not improve from 0.03801
#
# Epoch 00803: val_loss did not improve from 0.03801
#
# Epoch 00804: val_loss did not improve from 0.03801
#
# Epoch 00805: val_loss did not improve from 0.03801
